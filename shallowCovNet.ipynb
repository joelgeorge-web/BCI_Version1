# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# %%
# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 60, Samples = 151, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
## trainer 

"""
 Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data
 from a four-class classification task, using the sample dataset provided in
 the MNE [1, 2] package:
     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data
   
 The four classes used from this dataset are:
     LA: Left-ear auditory stimulation
     RA: Right-ear auditory stimulation
     LV: Left visual field stimulation
     RV: Right visual field stimulation

 The code to process, filter and epoch the data are originally from Alexandre
 Barachant's PyRiemann [3] package, released under the BSD 3-clause. A copy of 
 the BSD 3-clause license has been provided together with this software to 
 comply with software licensing requirements. 
 
 When you first run this script, MNE will download the dataset and prompt you
 to confirm the download location (defaults to ~/mne_data). Follow the prompts
 to continue. The dataset size is approx. 1.5GB download. 
 
 For comparative purposes you can also compare EEGNet performance to using 
 Riemannian geometric approaches with xDAWN spatial filtering [4-8] using 
 PyRiemann (code provided below).

 [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,
     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, 
     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.

 [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, 
     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data 
     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.

 [3] https://github.com/alexandrebarachant/pyRiemann. 

 [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"
     arXiv:1409.0107. link

 [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer 
     Interface Based on Riemannian Geometry", arXiv: 1310.8115.

 [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian 
     distance for BCI applications," in 2011 5th International IEEE/EMBS 
     Conference on Neural Engineering (NER), 2011, 348-351.

 [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass 
     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE 
     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.

 [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of 
     covariance matrices using a Riemannian-based kernel for BCI applications“, 
     in NeuroComputing, vol. 112, p. 172-178, 2013.


 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw.fif'
event_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB

# %%
# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels
X.shape
# Out:
# (288, 60, 151)

# %%
kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = ShallowConvNet(nb_classes = 4, Chans = 60, Samples = 151, dropoutRate = 0.5)

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint1.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)



#save the model as a pkl file
import pickle
filename = 'shallowCovNet.pkl'
pickle.dump(model, open(filename, 'wb'))
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.77872, saving model to checkpoint1.h5
# 9/9 - 2s - loss: 1.9941 - accuracy: 0.2778 - val_loss: 1.7787 - val_accuracy: 0.2361 - 2s/epoch - 266ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 1.77872
# 9/9 - 1s - loss: 1.3613 - accuracy: 0.3889 - val_loss: 2.6848 - val_accuracy: 0.2500 - 753ms/epoch - 84ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 1.77872
# 9/9 - 1s - loss: 1.3097 - accuracy: 0.4028 - val_loss: 2.8626 - val_accuracy: 0.2500 - 638ms/epoch - 71ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 1.77872 to 1.53258, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.1647 - accuracy: 0.5000 - val_loss: 1.5326 - val_accuracy: 0.3194 - 537ms/epoch - 60ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 1.53258
# 9/9 - 0s - loss: 1.1455 - accuracy: 0.4861 - val_loss: 1.7849 - val_accuracy: 0.3333 - 498ms/epoch - 55ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 1.53258
# 9/9 - 1s - loss: 1.0813 - accuracy: 0.5694 - val_loss: 1.9828 - val_accuracy: 0.2639 - 631ms/epoch - 70ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 1.53258
# 9/9 - 1s - loss: 0.9884 - accuracy: 0.5833 - val_loss: 1.8000 - val_accuracy: 0.2500 - 755ms/epoch - 84ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.53258 to 1.39873, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.8908 - accuracy: 0.6736 - val_loss: 1.3987 - val_accuracy: 0.3611 - 745ms/epoch - 83ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.39873 to 1.35946, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.8546 - accuracy: 0.6806 - val_loss: 1.3595 - val_accuracy: 0.3889 - 556ms/epoch - 62ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.35946 to 1.17492, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.7941 - accuracy: 0.7569 - val_loss: 1.1749 - val_accuracy: 0.4167 - 534ms/epoch - 59ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.17492 to 1.08224, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.7070 - accuracy: 0.8194 - val_loss: 1.0822 - val_accuracy: 0.5139 - 816ms/epoch - 91ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.08224 to 1.03502, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.6853 - accuracy: 0.7847 - val_loss: 1.0350 - val_accuracy: 0.5278 - 851ms/epoch - 95ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.03502 to 0.99946, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.6137 - accuracy: 0.8750 - val_loss: 0.9995 - val_accuracy: 0.6111 - 564ms/epoch - 63ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 0.99946 to 0.98891, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.5260 - accuracy: 0.8958 - val_loss: 0.9889 - val_accuracy: 0.5694 - 649ms/epoch - 72ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 0.98891 to 0.93345, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4679 - accuracy: 0.9167 - val_loss: 0.9334 - val_accuracy: 0.6250 - 757ms/epoch - 84ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 0.93345 to 0.92547, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4674 - accuracy: 0.9097 - val_loss: 0.9255 - val_accuracy: 0.6250 - 890ms/epoch - 99ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 0.92547 to 0.91691, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4220 - accuracy: 0.9028 - val_loss: 0.9169 - val_accuracy: 0.6111 - 568ms/epoch - 63ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 0.91691 to 0.85605, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.3498 - accuracy: 0.9583 - val_loss: 0.8561 - val_accuracy: 0.6528 - 546ms/epoch - 61ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.85605
# 9/9 - 1s - loss: 0.3014 - accuracy: 0.9722 - val_loss: 0.8871 - val_accuracy: 0.6250 - 597ms/epoch - 66ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 0.85605 to 0.85326, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.3042 - accuracy: 0.9514 - val_loss: 0.8533 - val_accuracy: 0.6667 - 914ms/epoch - 102ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 0.85326 to 0.77886, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2723 - accuracy: 0.9653 - val_loss: 0.7789 - val_accuracy: 0.7222 - 860ms/epoch - 96ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.77886
# 9/9 - 1s - loss: 0.2443 - accuracy: 0.9931 - val_loss: 1.0170 - val_accuracy: 0.5417 - 535ms/epoch - 59ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 0.77886 to 0.72540, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2115 - accuracy: 1.0000 - val_loss: 0.7254 - val_accuracy: 0.7361 - 610ms/epoch - 68ms/step
# Epoch 24/300
#
# Epoch 24: val_loss did not improve from 0.72540
# 9/9 - 1s - loss: 0.2247 - accuracy: 0.9861 - val_loss: 0.8275 - val_accuracy: 0.6389 - 842ms/epoch - 94ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.72540
# 9/9 - 1s - loss: 0.1957 - accuracy: 0.9722 - val_loss: 0.8089 - val_accuracy: 0.6806 - 752ms/epoch - 84ms/step
# Epoch 26/300
#
# Epoch 26: val_loss did not improve from 0.72540
# 9/9 - 1s - loss: 0.1785 - accuracy: 1.0000 - val_loss: 0.7365 - val_accuracy: 0.7500 - 504ms/epoch - 56ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 0.72540 to 0.69624, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.1616 - accuracy: 1.0000 - val_loss: 0.6962 - val_accuracy: 0.7222 - 534ms/epoch - 59ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.69624 to 0.63515, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.1240 - accuracy: 1.0000 - val_loss: 0.6351 - val_accuracy: 0.7361 - 743ms/epoch - 83ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.63515
# 9/9 - 1s - loss: 0.1317 - accuracy: 1.0000 - val_loss: 0.6832 - val_accuracy: 0.7083 - 772ms/epoch - 86ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 0.63515 to 0.58457, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.5846 - val_accuracy: 0.7639 - 602ms/epoch - 67ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 0.58457
# 9/9 - 1s - loss: 0.1004 - accuracy: 1.0000 - val_loss: 0.6297 - val_accuracy: 0.7222 - 514ms/epoch - 57ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.58457
# 9/9 - 0s - loss: 0.1013 - accuracy: 1.0000 - val_loss: 0.6417 - val_accuracy: 0.7500 - 493ms/epoch - 55ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.58457
# 9/9 - 1s - loss: 0.1073 - accuracy: 0.9931 - val_loss: 0.6268 - val_accuracy: 0.7639 - 730ms/epoch - 81ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.58457
# 9/9 - 1s - loss: 0.0982 - accuracy: 1.0000 - val_loss: 0.6453 - val_accuracy: 0.6944 - 824ms/epoch - 92ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.58457
# 9/9 - 0s - loss: 0.0811 - accuracy: 0.9931 - val_loss: 0.6037 - val_accuracy: 0.7361 - 462ms/epoch - 51ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 0.58457 to 0.55961, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0819 - accuracy: 0.9861 - val_loss: 0.5596 - val_accuracy: 0.7361 - 516ms/epoch - 57ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.55961
# 9/9 - 0s - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.6463 - val_accuracy: 0.7500 - 468ms/epoch - 52ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.55961
# 9/9 - 1s - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.6365 - val_accuracy: 0.7361 - 707ms/epoch - 79ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.55961
# 9/9 - 1s - loss: 0.0702 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 0.7639 - 792ms/epoch - 88ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.55961
# 9/9 - 0s - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.6598 - val_accuracy: 0.7500 - 493ms/epoch - 55ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.55961
# 9/9 - 0s - loss: 0.0642 - accuracy: 0.9931 - val_loss: 0.5770 - val_accuracy: 0.7639 - 450ms/epoch - 50ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.55961
# 9/9 - 0s - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.7639 - 448ms/epoch - 50ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.55961
# 9/9 - 1s - loss: 0.0717 - accuracy: 0.9931 - val_loss: 0.6369 - val_accuracy: 0.7361 - 667ms/epoch - 74ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.55961
# 9/9 - 1s - loss: 0.0587 - accuracy: 1.0000 - val_loss: 0.5764 - val_accuracy: 0.8056 - 817ms/epoch - 91ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 0.55961 to 0.53600, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0632 - accuracy: 1.0000 - val_loss: 0.5360 - val_accuracy: 0.7778 - 595ms/epoch - 66ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.53600
# 9/9 - 0s - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.8194 - 476ms/epoch - 53ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.53600
# 9/9 - 0s - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.7917 - 495ms/epoch - 55ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.53600
# 9/9 - 1s - loss: 0.0419 - accuracy: 1.0000 - val_loss: 0.5464 - val_accuracy: 0.7917 - 732ms/epoch - 81ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 0.53600 to 0.53246, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.5325 - val_accuracy: 0.7639 - 794ms/epoch - 88ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.53246
# 9/9 - 0s - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 0.7917 - 498ms/epoch - 55ms/step
# Epoch 51/300
#
# Epoch 51: val_loss did not improve from 0.53246
# 9/9 - 1s - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.7639 - 513ms/epoch - 57ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.53246
# 9/9 - 0s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.5431 - val_accuracy: 0.7500 - 495ms/epoch - 55ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.53246
# 9/9 - 1s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.5424 - val_accuracy: 0.7778 - 740ms/epoch - 82ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 0.53246 to 0.48863, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.4886 - val_accuracy: 0.8194 - 816ms/epoch - 91ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.48863
# 9/9 - 0s - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.8194 - 467ms/epoch - 52ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.48863
# 9/9 - 0s - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.5174 - val_accuracy: 0.7917 - 452ms/epoch - 50ms/step
# Epoch 57/300
#
# Epoch 57: val_loss improved from 0.48863 to 0.48466, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.4847 - val_accuracy: 0.8333 - 521ms/epoch - 58ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.8611 - 714ms/epoch - 79ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.7778 - 719ms/epoch - 80ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.5620 - val_accuracy: 0.7639 - 612ms/epoch - 68ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.6394 - val_accuracy: 0.7222 - 698ms/epoch - 78ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.8056 - 624ms/epoch - 69ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.8194 - 726ms/epoch - 81ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.5308 - val_accuracy: 0.7500 - 582ms/epoch - 65ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.5430 - val_accuracy: 0.7778 - 502ms/epoch - 56ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.48466
# 9/9 - 0s - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.5005 - val_accuracy: 0.7778 - 453ms/epoch - 50ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.7917 - 604ms/epoch - 67ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.7639 - 731ms/epoch - 81ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.48466
# 9/9 - 1s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.7778 - 687ms/epoch - 76ms/step
# Epoch 70/300
#
# Epoch 70: val_loss improved from 0.48466 to 0.45917, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.8194 - 520ms/epoch - 58ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.5103 - val_accuracy: 0.7778 - 517ms/epoch - 57ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.7917 - 634ms/epoch - 70ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.8056 - 797ms/epoch - 89ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.5608 - val_accuracy: 0.7917 - 643ms/epoch - 71ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.5617 - val_accuracy: 0.7917 - 512ms/epoch - 57ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.45917
# 9/9 - 0s - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8194 - 454ms/epoch - 50ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8056 - 674ms/epoch - 75ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.5610 - val_accuracy: 0.7778 - 1s/epoch - 112ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.45917
# 9/9 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.7778 - 475ms/epoch - 53ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.45917
# 9/9 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.8472 - 456ms/epoch - 51ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.45917
# 9/9 - 1s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.7639 - 519ms/epoch - 58ms/step
# Epoch 82/300
#
# Epoch 82: val_loss improved from 0.45917 to 0.44865, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.4486 - val_accuracy: 0.8611 - 807ms/epoch - 90ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.7917 - 743ms/epoch - 83ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.8056 - 522ms/epoch - 58ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.44865
# 9/9 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.4520 - val_accuracy: 0.8056 - 497ms/epoch - 55ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.8333 - 566ms/epoch - 63ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4576 - val_accuracy: 0.8333 - 748ms/epoch - 83ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.4589 - val_accuracy: 0.7639 - 685ms/epoch - 76ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.44865
# 9/9 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.4961 - val_accuracy: 0.7917 - 471ms/epoch - 52ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.7917 - 501ms/epoch - 56ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.44865
# 9/9 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.7917 - 483ms/epoch - 54ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.44865
# 9/9 - 1s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.4747 - val_accuracy: 0.8194 - 901ms/epoch - 100ms/step
# Epoch 93/300
#
# Epoch 93: val_loss improved from 0.44865 to 0.44284, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.8472 - 724ms/epoch - 80ms/step
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.44284 to 0.43768, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.8472 - 509ms/epoch - 57ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4390 - val_accuracy: 0.8194 - 494ms/epoch - 55ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4936 - val_accuracy: 0.7778 - 630ms/epoch - 70ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.8472 - 682ms/epoch - 76ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.7778 - 640ms/epoch - 71ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.7639 - 487ms/epoch - 54ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.5346 - val_accuracy: 0.8194 - 455ms/epoch - 51ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.7222 - 492ms/epoch - 55ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 0.8056 - 689ms/epoch - 77ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.5084 - val_accuracy: 0.7639 - 692ms/epoch - 77ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.5457 - val_accuracy: 0.7917 - 483ms/epoch - 54ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.5179 - val_accuracy: 0.8194 - 441ms/epoch - 49ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4698 - val_accuracy: 0.8333 - 465ms/epoch - 52ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.7500 - 649ms/epoch - 72ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.7778 - 691ms/epoch - 77ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4637 - val_accuracy: 0.8056 - 534ms/epoch - 59ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.7778 - 492ms/epoch - 55ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.7639 - 455ms/epoch - 51ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.5286 - val_accuracy: 0.7639 - 590ms/epoch - 66ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.7778 - 746ms/epoch - 83ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.5253 - val_accuracy: 0.7778 - 692ms/epoch - 77ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.7683 - val_accuracy: 0.7222 - 513ms/epoch - 57ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4591 - val_accuracy: 0.8472 - 512ms/epoch - 57ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.8194 - 766ms/epoch - 85ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.8194 - 825ms/epoch - 92ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8056 - 798ms/epoch - 89ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.5565 - val_accuracy: 0.7639 - 768ms/epoch - 85ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.7639 - 501ms/epoch - 56ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.7778 - 514ms/epoch - 57ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.8611 - 502ms/epoch - 56ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.7778 - 746ms/epoch - 83ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.7917 - 727ms/epoch - 81ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.43768
# 9/9 - 1s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.8333 - 505ms/epoch - 56ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.43768
# 9/9 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4622 - val_accuracy: 0.7917 - 477ms/epoch - 53ms/step
# Epoch 128/300
#
# Epoch 128: val_loss improved from 0.43768 to 0.42800, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.4280 - val_accuracy: 0.8056 - 566ms/epoch - 63ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.7778 - 715ms/epoch - 79ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.8194 - 819ms/epoch - 91ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.8056 - 485ms/epoch - 54ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4791 - val_accuracy: 0.7917 - 489ms/epoch - 54ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4422 - val_accuracy: 0.8056 - 577ms/epoch - 64ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4495 - val_accuracy: 0.8333 - 767ms/epoch - 85ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.5799 - val_accuracy: 0.7917 - 737ms/epoch - 82ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5019 - val_accuracy: 0.8056 - 564ms/epoch - 63ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.7639 - 629ms/epoch - 70ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.7917 - 637ms/epoch - 71ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.8056 - 796ms/epoch - 88ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.8056 - 520ms/epoch - 58ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5668 - val_accuracy: 0.7778 - 455ms/epoch - 51ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.5675 - val_accuracy: 0.8056 - 485ms/epoch - 54ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 1.5370 - val_accuracy: 0.4583 - 647ms/epoch - 72ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0395 - accuracy: 1.0000 - val_loss: 1.2668 - val_accuracy: 0.3472 - 810ms/epoch - 90ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0955 - accuracy: 0.9931 - val_loss: 1.1690 - val_accuracy: 0.5000 - 646ms/epoch - 72ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.1078 - accuracy: 1.0000 - val_loss: 0.9912 - val_accuracy: 0.5278 - 515ms/epoch - 57ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0918 - accuracy: 0.9931 - val_loss: 1.0927 - val_accuracy: 0.5694 - 530ms/epoch - 59ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0747 - accuracy: 1.0000 - val_loss: 1.2271 - val_accuracy: 0.4444 - 763ms/epoch - 85ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0793 - accuracy: 0.9931 - val_loss: 0.7888 - val_accuracy: 0.6667 - 848ms/epoch - 94ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0571 - accuracy: 1.0000 - val_loss: 1.0107 - val_accuracy: 0.5694 - 856ms/epoch - 95ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.5970 - val_accuracy: 0.7917 - 770ms/epoch - 86ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.8056 - 519ms/epoch - 58ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.7778 - 490ms/epoch - 54ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.7778 - 607ms/epoch - 67ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.5483 - val_accuracy: 0.7639 - 775ms/epoch - 86ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.7778 - 584ms/epoch - 65ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.7639 - 472ms/epoch - 52ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.42800
# 9/9 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8194 - 457ms/epoch - 51ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4347 - val_accuracy: 0.8333 - 519ms/epoch - 58ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.42800
# 9/9 - 1s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.7778 - 765ms/epoch - 85ms/step
# Epoch 161/300
#
# Epoch 161: val_loss improved from 0.42800 to 0.42091, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4209 - val_accuracy: 0.8194 - 772ms/epoch - 86ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.7778 - 503ms/epoch - 56ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.7917 - 525ms/epoch - 58ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.7917 - 672ms/epoch - 75ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.7917 - 692ms/epoch - 77ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4794 - val_accuracy: 0.7917 - 669ms/epoch - 74ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.8194 - 500ms/epoch - 56ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.7778 - 446ms/epoch - 50ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.7778 - 660ms/epoch - 73ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.7778 - 745ms/epoch - 83ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.7917 - 636ms/epoch - 71ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.8333 - 521ms/epoch - 58ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4422 - val_accuracy: 0.7917 - 512ms/epoch - 57ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4578 - val_accuracy: 0.8333 - 699ms/epoch - 78ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.7917 - 856ms/epoch - 95ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.8194 - 637ms/epoch - 71ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4315 - val_accuracy: 0.8194 - 535ms/epoch - 59ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.5935 - val_accuracy: 0.7500 - 557ms/epoch - 62ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.7917 - 750ms/epoch - 83ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.8194 - 738ms/epoch - 82ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.7639 - 463ms/epoch - 51ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5826 - val_accuracy: 0.7639 - 437ms/epoch - 49ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.7243 - val_accuracy: 0.7083 - 473ms/epoch - 53ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.7040 - val_accuracy: 0.7222 - 670ms/epoch - 74ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8333 - 746ms/epoch - 83ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.7778 - 583ms/epoch - 65ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4504 - val_accuracy: 0.8056 - 474ms/epoch - 53ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4403 - val_accuracy: 0.8194 - 460ms/epoch - 51ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4312 - val_accuracy: 0.8056 - 629ms/epoch - 70ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4455 - val_accuracy: 0.8056 - 739ms/epoch - 82ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4433 - val_accuracy: 0.8056 - 582ms/epoch - 65ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.7778 - 452ms/epoch - 50ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.8194 - 444ms/epoch - 49ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.8056 - 655ms/epoch - 73ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.4681 - val_accuracy: 0.7778 - 688ms/epoch - 76ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4960 - val_accuracy: 0.7917 - 604ms/epoch - 67ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.8056 - 493ms/epoch - 55ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5236 - val_accuracy: 0.7778 - 450ms/epoch - 50ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8194 - 530ms/epoch - 59ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.7917 - 696ms/epoch - 77ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.8056 - 647ms/epoch - 72ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4482 - val_accuracy: 0.8056 - 453ms/epoch - 50ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.8056 - 439ms/epoch - 49ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.8056 - 452ms/epoch - 50ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4583 - val_accuracy: 0.7917 - 697ms/epoch - 77ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.8056 - 756ms/epoch - 84ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4334 - val_accuracy: 0.8056 - 579ms/epoch - 64ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.7917 - 546ms/epoch - 61ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4485 - val_accuracy: 0.8194 - 448ms/epoch - 50ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.8056 - 732ms/epoch - 81ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8056 - 833ms/epoch - 93ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4551 - val_accuracy: 0.8056 - 501ms/epoch - 56ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.8056 - 485ms/epoch - 54ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8056 - 608ms/epoch - 68ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.7917 - 948ms/epoch - 105ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4419 - val_accuracy: 0.8056 - 1s/epoch - 122ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4459 - val_accuracy: 0.8056 - 877ms/epoch - 97ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.8472 - 624ms/epoch - 69ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.7917 - 796ms/epoch - 88ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.8194 - 892ms/epoch - 99ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4533 - val_accuracy: 0.7917 - 680ms/epoch - 76ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5540 - val_accuracy: 0.7778 - 533ms/epoch - 59ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.8194 - 483ms/epoch - 54ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.7639 - 594ms/epoch - 66ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.8194 - 737ms/epoch - 82ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.7917 - 713ms/epoch - 79ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.8056 - 489ms/epoch - 54ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4424 - val_accuracy: 0.8056 - 483ms/epoch - 54ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.8056 - 573ms/epoch - 64ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.8056 - 752ms/epoch - 84ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4429 - val_accuracy: 0.8194 - 648ms/epoch - 72ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.7778 - 455ms/epoch - 51ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4514 - val_accuracy: 0.8056 - 458ms/epoch - 51ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4292 - val_accuracy: 0.8056 - 504ms/epoch - 56ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.8056 - 889ms/epoch - 99ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.7778 - 648ms/epoch - 72ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4811 - val_accuracy: 0.8333 - 509ms/epoch - 57ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.7917 - 570ms/epoch - 63ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.7917 - 636ms/epoch - 71ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4747 - val_accuracy: 0.8194 - 743ms/epoch - 83ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.8056 - 675ms/epoch - 75ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.7778 - 548ms/epoch - 61ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4625 - val_accuracy: 0.8194 - 500ms/epoch - 56ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.8056 - 814ms/epoch - 90ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.7778 - 818ms/epoch - 91ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4566 - val_accuracy: 0.7917 - 520ms/epoch - 58ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4495 - val_accuracy: 0.8056 - 512ms/epoch - 57ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.8333 - 502ms/epoch - 56ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.7778 - 834ms/epoch - 93ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4506 - val_accuracy: 0.7917 - 734ms/epoch - 82ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4725 - val_accuracy: 0.8194 - 512ms/epoch - 57ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4644 - val_accuracy: 0.8056 - 501ms/epoch - 56ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 0.8056 - 591ms/epoch - 66ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4635 - val_accuracy: 0.8056 - 777ms/epoch - 86ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.7639 - 722ms/epoch - 80ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.7778 - 507ms/epoch - 56ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4439 - val_accuracy: 0.7917 - 495ms/epoch - 55ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.7917 - 662ms/epoch - 74ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4750 - val_accuracy: 0.8056 - 792ms/epoch - 88ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8056 - 573ms/epoch - 64ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.8056 - 560ms/epoch - 62ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.7917 - 563ms/epoch - 63ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4576 - val_accuracy: 0.8056 - 679ms/epoch - 75ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8056 - 693ms/epoch - 77ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4421 - val_accuracy: 0.8194 - 595ms/epoch - 66ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4942 - val_accuracy: 0.7778 - 481ms/epoch - 53ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.7917 - 517ms/epoch - 57ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5278 - val_accuracy: 0.7917 - 742ms/epoch - 82ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5634 - val_accuracy: 0.7778 - 746ms/epoch - 83ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5338 - val_accuracy: 0.7778 - 555ms/epoch - 62ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.8056 - 521ms/epoch - 58ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.7917 - 525ms/epoch - 58ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4818 - val_accuracy: 0.7917 - 970ms/epoch - 108ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4938 - val_accuracy: 0.7778 - 848ms/epoch - 94ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.7917 - 746ms/epoch - 83ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4577 - val_accuracy: 0.8056 - 596ms/epoch - 66ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.7917 - 463ms/epoch - 51ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8056 - 485ms/epoch - 54ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.7917 - 564ms/epoch - 63ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4551 - val_accuracy: 0.8056 - 822ms/epoch - 91ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4646 - val_accuracy: 0.7917 - 798ms/epoch - 89ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.8056 - 788ms/epoch - 88ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4994 - val_accuracy: 0.7778 - 600ms/epoch - 67ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.7778 - 464ms/epoch - 52ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.7917 - 520ms/epoch - 58ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4749 - val_accuracy: 0.8194 - 605ms/epoch - 67ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8056 - 895ms/epoch - 99ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.8056 - 585ms/epoch - 65ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8056 - 495ms/epoch - 55ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.7778 - 474ms/epoch - 53ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4278 - val_accuracy: 0.8611 - 683ms/epoch - 76ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.8056 - 800ms/epoch - 89ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.7917 - 540ms/epoch - 60ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4482 - val_accuracy: 0.7917 - 488ms/epoch - 54ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.8056 - 483ms/epoch - 54ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.7778 - 604ms/epoch - 67ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.7917 - 720ms/epoch - 80ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5462 - val_accuracy: 0.7500 - 563ms/epoch - 63ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.7917 - 473ms/epoch - 53ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.42091
# 9/9 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.7778 - 592ms/epoch - 66ms/step

# %%
###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 23ms/step
# Classification accuracy: 0.930556

# %%
model.predict(X_test).argmax(axis = -1)
# Out:
# 3/3 [==============================] - 0s 19ms/step
# array([3, 1, 2, 1, 3, 1, 2, 1, 1, 2, 0, 3, 1, 2, 0, 3, 1, 3, 0, 3, 1, 2,
#        0, 3, 1, 2, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        2, 0, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 1, 3, 1,
#        0, 3, 1, 2, 0, 3], dtype=int64)

# %%
Y_test.argmax(axis=-1)
# Out:
# array([3, 1, 2, 0, 3, 1, 2, 0, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2,
#        0, 3, 1, 2, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        2, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        0, 3, 1, 2, 0, 3], dtype=int64)

# %%
import turtle 
import time


# model = pickle.load(open('C:\\Users\\Lakshmi\\Desktop\\Main Project\\codes\\EEGNet.pkl','rb'))



############################# turtle bot portion ##################################
# Create a turtle object
sc = turtle.Screen() 

t = turtle.Turtle()
s = turtle.Turtle()
t.hideturtle() # hides arrow
t.speed(0)


def drawCircle(x,y,r):
    t.pu()
    t.goto(x,y-r)
    t.pd()
    t.circle(r)
    t.penup()

    t.home()
    t.showturtle()
    t.pendown()
    t.left(90)

# Function to move the turtle based on input
def move_turtle(direction, ytest):
    t.penup()
    
    t.showturtle()
    #boundaries

    min_x, max_x = -200, 200
    min_y, max_y = -200, 200

    curr_x, curr_y = t.pos()
    
    s.penup()
    s.hideturtle()
    s.goto(200, 200)
    s.write(f"Predicted Value: {direction}", font=("Arial", 14, "normal"))
    s.goto(200, 150)  
    s.write(f"Actual Value: {ytest}", font=("Arial", 14, "normal"))


    if direction == 0: #fwd
        if curr_y + 50 <= max_y:
            t.speed(0.5)
            t.fd(50)
            t.speed(0.5)  
    elif direction == 1: #lft
        if curr_x - 50 >= min_x:
            t.left(90)
            t.fd(50)
            t.speed(0.5)
            t.right(90)     
    elif direction == 2: #rt
        if curr_x + 50 <= max_x:
            t.right(90)
            t.fd(50)
            t.speed(0.5)
            t.left(90)   
    elif direction == 3: #bkd
        if curr_y - 50 >= min_y:
            t.left(180)
            t.fd(50)
            t.speed(0.5)
            t.left(180) 

def main():
    try:
       
        data = model.predict(X_test).argmax(axis = -1)  
        drawCircle(0,0,200)
        for direction in data:
            i = Y_test[direction]
            print(direction,i)
            move_turtle(direction)
            time.sleep(5)
    except ValueError:
        print("Invalid input! Please enter a number between 0 and 3.")

# Call the main function
if __name__ == "__main__":
    main()
# Out:
# 3/3 [==============================] - 0s 22ms/step
# 3 [1. 0. 0. 0.]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 90
#      88 # Call the main function
#      89 if __name__ == "__main__":
# ---> 90     main()
#
# Cell In[10], line 83, in main()
#      81         i = Y_test[direction]
#      82         print(direction,i)
# ---> 83         move_turtle(direction)
#      84         time.sleep(5)
#      85 except ValueError:
#
# TypeError: move_turtle() missing 1 required positional argument: 'ytest'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
