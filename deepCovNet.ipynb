# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# %%
def DeepConvNet(nb_classes, Chans = 60, Samples = 151, dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
     
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
## trainer 

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw.fif'
event_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
print(X_train)

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples

model = DeepConvNet(nb_classes = 4, Chans = 60, Samples = 151, dropoutRate = 0.5)

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint1.h5', verbose=1,
                               save_best_only=True)


# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)

# load optimal weights
model.load_weights('checkpoint1.h5')



probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))

#save the model as a pkl file
import pickle
filename = 'deepCovNet.pkl'
pickle.dump(model, open(filename, 'wb'))
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.39403, saving model to checkpoint1.h5
# 9/9 - 4s - loss: 1.7035 - accuracy: 0.2361 - val_loss: 1.3940 - val_accuracy: 0.2500 - 4s/epoch - 482ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 1.39403
# 9/9 - 1s - loss: 1.5003 - accuracy: 0.2917 - val_loss: 1.4244 - val_accuracy: 0.2500 - 759ms/epoch - 84ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 1.39403
# 9/9 - 1s - loss: 1.3509 - accuracy: 0.3681 - val_loss: 1.4346 - val_accuracy: 0.2500 - 677ms/epoch - 75ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 1.39403
# 9/9 - 0s - loss: 1.3609 - accuracy: 0.3542 - val_loss: 1.4275 - val_accuracy: 0.2500 - 469ms/epoch - 52ms/step
# Epoch 5/300
#
# Epoch 5: val_loss improved from 1.39403 to 1.38428, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.3687 - accuracy: 0.3264 - val_loss: 1.3843 - val_accuracy: 0.3889 - 714ms/epoch - 79ms/step
# Epoch 6/300
#
# Epoch 6: val_loss improved from 1.38428 to 1.35073, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.3406 - accuracy: 0.3681 - val_loss: 1.3507 - val_accuracy: 0.3750 - 824ms/epoch - 92ms/step
# Epoch 7/300
#
# Epoch 7: val_loss improved from 1.35073 to 1.33624, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.2332 - accuracy: 0.4167 - val_loss: 1.3362 - val_accuracy: 0.3056 - 887ms/epoch - 99ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.33624 to 1.27301, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.2288 - accuracy: 0.4306 - val_loss: 1.2730 - val_accuracy: 0.4167 - 538ms/epoch - 60ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.27301 to 1.20319, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.1698 - accuracy: 0.4167 - val_loss: 1.2032 - val_accuracy: 0.4028 - 573ms/epoch - 64ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.20319 to 1.14321, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 1.0697 - accuracy: 0.4792 - val_loss: 1.1432 - val_accuracy: 0.4583 - 861ms/epoch - 96ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.14321 to 1.10479, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.9903 - accuracy: 0.5556 - val_loss: 1.1048 - val_accuracy: 0.4861 - 962ms/epoch - 107ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 1.10479
# 9/9 - 1s - loss: 0.9861 - accuracy: 0.5833 - val_loss: 1.1051 - val_accuracy: 0.4444 - 544ms/epoch - 60ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.10479 to 1.05292, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.9072 - accuracy: 0.5833 - val_loss: 1.0529 - val_accuracy: 0.4583 - 625ms/epoch - 69ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 1.05292 to 1.03992, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.9158 - accuracy: 0.5694 - val_loss: 1.0399 - val_accuracy: 0.4722 - 867ms/epoch - 96ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 1.03992
# 9/9 - 1s - loss: 0.7936 - accuracy: 0.6667 - val_loss: 1.0466 - val_accuracy: 0.4028 - 1s/epoch - 113ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.03992 to 0.99437, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.8084 - accuracy: 0.6389 - val_loss: 0.9944 - val_accuracy: 0.5000 - 773ms/epoch - 86ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 0.99437 to 0.99249, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.8477 - accuracy: 0.6181 - val_loss: 0.9925 - val_accuracy: 0.5139 - 827ms/epoch - 92ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.99249
# 9/9 - 1s - loss: 0.7763 - accuracy: 0.6042 - val_loss: 0.9973 - val_accuracy: 0.5417 - 904ms/epoch - 100ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.99249
# 9/9 - 1s - loss: 0.7515 - accuracy: 0.6389 - val_loss: 0.9931 - val_accuracy: 0.4861 - 871ms/epoch - 97ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 0.99249 to 0.96195, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.7495 - accuracy: 0.6806 - val_loss: 0.9619 - val_accuracy: 0.5000 - 843ms/epoch - 94ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 0.96195 to 0.94968, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.6644 - accuracy: 0.6667 - val_loss: 0.9497 - val_accuracy: 0.5556 - 976ms/epoch - 108ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.94968
# 9/9 - 1s - loss: 0.7365 - accuracy: 0.6736 - val_loss: 0.9620 - val_accuracy: 0.5694 - 765ms/epoch - 85ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 0.94968 to 0.93697, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.6220 - accuracy: 0.7500 - val_loss: 0.9370 - val_accuracy: 0.5417 - 725ms/epoch - 81ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 0.93697 to 0.88284, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.6290 - accuracy: 0.7500 - val_loss: 0.8828 - val_accuracy: 0.5833 - 1s/epoch - 112ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 0.88284 to 0.86508, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.5908 - accuracy: 0.7847 - val_loss: 0.8651 - val_accuracy: 0.6111 - 1s/epoch - 131ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 0.86508 to 0.80966, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.5027 - accuracy: 0.8194 - val_loss: 0.8097 - val_accuracy: 0.6389 - 776ms/epoch - 86ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 0.80966 to 0.79619, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.5235 - accuracy: 0.7569 - val_loss: 0.7962 - val_accuracy: 0.6389 - 687ms/epoch - 76ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.79619 to 0.77694, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.5301 - accuracy: 0.7847 - val_loss: 0.7769 - val_accuracy: 0.6389 - 1s/epoch - 121ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 0.77694 to 0.71666, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4595 - accuracy: 0.8472 - val_loss: 0.7167 - val_accuracy: 0.6944 - 791ms/epoch - 88ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 0.71666 to 0.71039, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4341 - accuracy: 0.8194 - val_loss: 0.7104 - val_accuracy: 0.7083 - 631ms/epoch - 70ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 0.71039 to 0.67469, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.4691 - accuracy: 0.8125 - val_loss: 0.6747 - val_accuracy: 0.7361 - 724ms/epoch - 80ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.67469
# 9/9 - 1s - loss: 0.3894 - accuracy: 0.8889 - val_loss: 0.6762 - val_accuracy: 0.6944 - 812ms/epoch - 90ms/step
# Epoch 33/300
#
# Epoch 33: val_loss improved from 0.67469 to 0.64524, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.3818 - accuracy: 0.8681 - val_loss: 0.6452 - val_accuracy: 0.7083 - 948ms/epoch - 105ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 0.64524 to 0.60746, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.3998 - accuracy: 0.8194 - val_loss: 0.6075 - val_accuracy: 0.7222 - 664ms/epoch - 74ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 0.60746 to 0.59832, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.3668 - accuracy: 0.8750 - val_loss: 0.5983 - val_accuracy: 0.7083 - 834ms/epoch - 93ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.3678 - accuracy: 0.8750 - val_loss: 0.6073 - val_accuracy: 0.7083 - 746ms/epoch - 83ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.3213 - accuracy: 0.8889 - val_loss: 0.6308 - val_accuracy: 0.7361 - 603ms/epoch - 67ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.59832
# 9/9 - 0s - loss: 0.3604 - accuracy: 0.8611 - val_loss: 0.6489 - val_accuracy: 0.7361 - 494ms/epoch - 55ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.3124 - accuracy: 0.9167 - val_loss: 0.6484 - val_accuracy: 0.7083 - 546ms/epoch - 61ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.2773 - accuracy: 0.9236 - val_loss: 0.6355 - val_accuracy: 0.7083 - 974ms/epoch - 108ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.2972 - accuracy: 0.9306 - val_loss: 0.6926 - val_accuracy: 0.7222 - 943ms/epoch - 105ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.2956 - accuracy: 0.9167 - val_loss: 0.6326 - val_accuracy: 0.6944 - 694ms/epoch - 77ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.59832
# 9/9 - 1s - loss: 0.2615 - accuracy: 0.9236 - val_loss: 0.6319 - val_accuracy: 0.7361 - 752ms/epoch - 84ms/step
# Epoch 44/300
#
# Epoch 44: val_loss improved from 0.59832 to 0.59779, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2376 - accuracy: 0.9167 - val_loss: 0.5978 - val_accuracy: 0.7222 - 1s/epoch - 114ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 0.59779 to 0.58999, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2402 - accuracy: 0.9236 - val_loss: 0.5900 - val_accuracy: 0.7083 - 710ms/epoch - 79ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.58999
# 9/9 - 0s - loss: 0.2311 - accuracy: 0.9236 - val_loss: 0.6375 - val_accuracy: 0.7222 - 494ms/epoch - 55ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.58999
# 9/9 - 0s - loss: 0.1941 - accuracy: 0.9653 - val_loss: 0.5907 - val_accuracy: 0.6944 - 498ms/epoch - 55ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 0.58999 to 0.57203, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2120 - accuracy: 0.9375 - val_loss: 0.5720 - val_accuracy: 0.7361 - 1s/epoch - 127ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 0.57203 to 0.56848, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2454 - accuracy: 0.9097 - val_loss: 0.5685 - val_accuracy: 0.7222 - 683ms/epoch - 76ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.56848
# 9/9 - 0s - loss: 0.1982 - accuracy: 0.9236 - val_loss: 0.6029 - val_accuracy: 0.7222 - 484ms/epoch - 54ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 0.56848 to 0.56060, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.2733 - accuracy: 0.9028 - val_loss: 0.5606 - val_accuracy: 0.7222 - 641ms/epoch - 71ms/step
# Epoch 52/300
#
# Epoch 52: val_loss improved from 0.56060 to 0.55235, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.1991 - accuracy: 0.9375 - val_loss: 0.5524 - val_accuracy: 0.7361 - 889ms/epoch - 99ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.55235
# 9/9 - 1s - loss: 0.1644 - accuracy: 0.9653 - val_loss: 0.5647 - val_accuracy: 0.7361 - 690ms/epoch - 77ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.55235
# 9/9 - 1s - loss: 0.1664 - accuracy: 0.9653 - val_loss: 0.5534 - val_accuracy: 0.7083 - 558ms/epoch - 62ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.55235
# 9/9 - 0s - loss: 0.1784 - accuracy: 0.9653 - val_loss: 0.6577 - val_accuracy: 0.7639 - 494ms/epoch - 55ms/step
# Epoch 56/300
#
# Epoch 56: val_loss improved from 0.55235 to 0.53710, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.1758 - accuracy: 0.9792 - val_loss: 0.5371 - val_accuracy: 0.7361 - 844ms/epoch - 94ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.2214 - accuracy: 0.9306 - val_loss: 0.6144 - val_accuracy: 0.7222 - 800ms/epoch - 89ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1498 - accuracy: 0.9722 - val_loss: 0.5842 - val_accuracy: 0.7222 - 524ms/epoch - 58ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1939 - accuracy: 0.9306 - val_loss: 0.5568 - val_accuracy: 0.7639 - 450ms/epoch - 50ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1707 - accuracy: 0.9653 - val_loss: 0.5699 - val_accuracy: 0.7222 - 441ms/epoch - 49ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1388 - accuracy: 0.9583 - val_loss: 0.6109 - val_accuracy: 0.7361 - 591ms/epoch - 66ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1313 - accuracy: 0.9722 - val_loss: 0.6009 - val_accuracy: 0.6944 - 758ms/epoch - 84ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1277 - accuracy: 0.9792 - val_loss: 0.5808 - val_accuracy: 0.7222 - 557ms/epoch - 62ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1168 - accuracy: 0.9861 - val_loss: 0.5817 - val_accuracy: 0.7361 - 452ms/epoch - 50ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1180 - accuracy: 0.9792 - val_loss: 0.6222 - val_accuracy: 0.7500 - 468ms/epoch - 52ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1486 - accuracy: 0.9375 - val_loss: 0.5778 - val_accuracy: 0.7222 - 481ms/epoch - 53ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1364 - accuracy: 0.9583 - val_loss: 0.6176 - val_accuracy: 0.7500 - 742ms/epoch - 82ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1156 - accuracy: 0.9792 - val_loss: 0.5626 - val_accuracy: 0.7361 - 689ms/epoch - 77ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1203 - accuracy: 0.9861 - val_loss: 0.5887 - val_accuracy: 0.7500 - 461ms/epoch - 51ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0969 - accuracy: 0.9861 - val_loss: 0.5555 - val_accuracy: 0.7361 - 446ms/epoch - 50ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1270 - accuracy: 0.9722 - val_loss: 0.6201 - val_accuracy: 0.7500 - 450ms/epoch - 50ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1254 - accuracy: 0.9792 - val_loss: 0.5915 - val_accuracy: 0.6944 - 716ms/epoch - 80ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1165 - accuracy: 0.9722 - val_loss: 0.6582 - val_accuracy: 0.7083 - 695ms/epoch - 77ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.6088 - val_accuracy: 0.7083 - 515ms/epoch - 57ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1183 - accuracy: 0.9722 - val_loss: 0.6790 - val_accuracy: 0.7222 - 450ms/epoch - 50ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1622 - accuracy: 0.9444 - val_loss: 0.6608 - val_accuracy: 0.6528 - 490ms/epoch - 54ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1107 - accuracy: 0.9653 - val_loss: 0.6342 - val_accuracy: 0.7361 - 585ms/epoch - 65ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.1187 - accuracy: 0.9792 - val_loss: 0.5955 - val_accuracy: 0.6944 - 678ms/epoch - 75ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.6003 - val_accuracy: 0.7083 - 584ms/epoch - 65ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1051 - accuracy: 0.9653 - val_loss: 0.6123 - val_accuracy: 0.6944 - 491ms/epoch - 55ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0854 - accuracy: 0.9861 - val_loss: 0.5906 - val_accuracy: 0.7083 - 418ms/epoch - 46ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0801 - accuracy: 0.9861 - val_loss: 0.5882 - val_accuracy: 0.6944 - 423ms/epoch - 47ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0907 - accuracy: 0.9861 - val_loss: 0.6361 - val_accuracy: 0.7222 - 629ms/epoch - 70ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0800 - accuracy: 0.9931 - val_loss: 0.6471 - val_accuracy: 0.6944 - 664ms/epoch - 74ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0852 - accuracy: 0.9861 - val_loss: 0.6093 - val_accuracy: 0.7222 - 490ms/epoch - 54ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0742 - accuracy: 0.9861 - val_loss: 0.5836 - val_accuracy: 0.7222 - 422ms/epoch - 47ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.1028 - accuracy: 0.9792 - val_loss: 0.5744 - val_accuracy: 0.7361 - 431ms/epoch - 48ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0745 - accuracy: 0.9861 - val_loss: 0.5835 - val_accuracy: 0.7361 - 525ms/epoch - 58ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0776 - accuracy: 0.9861 - val_loss: 0.6276 - val_accuracy: 0.6806 - 635ms/epoch - 71ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.53710
# 9/9 - 1s - loss: 0.0878 - accuracy: 0.9722 - val_loss: 0.6103 - val_accuracy: 0.7222 - 653ms/epoch - 73ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0572 - accuracy: 0.9861 - val_loss: 0.6244 - val_accuracy: 0.7222 - 473ms/epoch - 53ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0629 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 0.7222 - 437ms/epoch - 49ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.53710
# 9/9 - 0s - loss: 0.0639 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.7222 - 452ms/epoch - 50ms/step
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.53710 to 0.53284, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.5328 - val_accuracy: 0.7361 - 744ms/epoch - 83ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 0.7222 - 675ms/epoch - 75ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0675 - accuracy: 0.9861 - val_loss: 0.5408 - val_accuracy: 0.7361 - 477ms/epoch - 53ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0576 - accuracy: 0.9931 - val_loss: 0.5435 - val_accuracy: 0.7639 - 473ms/epoch - 53ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0645 - accuracy: 0.9861 - val_loss: 0.5671 - val_accuracy: 0.7083 - 426ms/epoch - 47ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.5639 - val_accuracy: 0.6944 - 501ms/epoch - 56ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0532 - accuracy: 0.9931 - val_loss: 0.6125 - val_accuracy: 0.7222 - 643ms/epoch - 71ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0544 - accuracy: 0.9931 - val_loss: 0.5810 - val_accuracy: 0.6944 - 650ms/epoch - 72ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.6260 - val_accuracy: 0.7083 - 441ms/epoch - 49ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.6338 - val_accuracy: 0.7222 - 474ms/epoch - 53ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0875 - accuracy: 0.9861 - val_loss: 0.6246 - val_accuracy: 0.6944 - 418ms/epoch - 46ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0522 - accuracy: 0.9931 - val_loss: 0.6198 - val_accuracy: 0.6806 - 596ms/epoch - 66ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0539 - accuracy: 0.9931 - val_loss: 0.5912 - val_accuracy: 0.7083 - 690ms/epoch - 77ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0626 - accuracy: 0.9931 - val_loss: 0.6497 - val_accuracy: 0.7500 - 574ms/epoch - 64ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.7083 - 436ms/epoch - 48ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0668 - accuracy: 0.9861 - val_loss: 0.6556 - val_accuracy: 0.7083 - 417ms/epoch - 46ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0519 - accuracy: 0.9861 - val_loss: 0.6685 - val_accuracy: 0.7222 - 435ms/epoch - 48ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.5856 - val_accuracy: 0.7083 - 666ms/epoch - 74ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0632 - accuracy: 0.9931 - val_loss: 0.5734 - val_accuracy: 0.7083 - 659ms/epoch - 73ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.6766 - val_accuracy: 0.7778 - 463ms/epoch - 51ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0528 - accuracy: 0.9931 - val_loss: 0.5975 - val_accuracy: 0.7083 - 450ms/epoch - 50ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.5360 - val_accuracy: 0.7222 - 418ms/epoch - 46ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.7500 - 450ms/epoch - 50ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0539 - accuracy: 0.9931 - val_loss: 0.6093 - val_accuracy: 0.7083 - 635ms/epoch - 71ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0527 - accuracy: 0.9931 - val_loss: 0.6857 - val_accuracy: 0.6944 - 679ms/epoch - 75ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0955 - accuracy: 0.9653 - val_loss: 0.7097 - val_accuracy: 0.7222 - 425ms/epoch - 47ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0598 - accuracy: 0.9931 - val_loss: 0.8243 - val_accuracy: 0.6806 - 423ms/epoch - 47ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.1043 - accuracy: 0.9583 - val_loss: 0.7560 - val_accuracy: 0.6528 - 419ms/epoch - 47ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0589 - accuracy: 0.9931 - val_loss: 0.7503 - val_accuracy: 0.7083 - 514ms/epoch - 57ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.7625 - val_accuracy: 0.6528 - 656ms/epoch - 73ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0395 - accuracy: 1.0000 - val_loss: 0.7848 - val_accuracy: 0.6944 - 633ms/epoch - 70ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0503 - accuracy: 0.9861 - val_loss: 0.7504 - val_accuracy: 0.7222 - 428ms/epoch - 48ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0444 - accuracy: 0.9861 - val_loss: 0.7654 - val_accuracy: 0.6806 - 446ms/epoch - 50ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.7037 - val_accuracy: 0.6806 - 423ms/epoch - 47ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0426 - accuracy: 0.9931 - val_loss: 0.6459 - val_accuracy: 0.7083 - 660ms/epoch - 73ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.6249 - val_accuracy: 0.7222 - 661ms/epoch - 73ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0357 - accuracy: 0.9931 - val_loss: 0.6625 - val_accuracy: 0.7222 - 559ms/epoch - 62ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.6768 - val_accuracy: 0.6806 - 425ms/epoch - 47ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.7885 - val_accuracy: 0.7222 - 419ms/epoch - 47ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0517 - accuracy: 0.9861 - val_loss: 0.7152 - val_accuracy: 0.6250 - 499ms/epoch - 55ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.7283 - val_accuracy: 0.6806 - 690ms/epoch - 77ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.7382 - val_accuracy: 0.6944 - 719ms/epoch - 80ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.6964 - val_accuracy: 0.7083 - 420ms/epoch - 47ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0392 - accuracy: 0.9931 - val_loss: 0.7153 - val_accuracy: 0.6944 - 439ms/epoch - 49ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0397 - accuracy: 0.9931 - val_loss: 0.7593 - val_accuracy: 0.6389 - 432ms/epoch - 48ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0403 - accuracy: 0.9931 - val_loss: 0.6614 - val_accuracy: 0.7083 - 527ms/epoch - 59ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0382 - accuracy: 0.9931 - val_loss: 0.6535 - val_accuracy: 0.6944 - 639ms/epoch - 71ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0428 - accuracy: 0.9931 - val_loss: 0.7391 - val_accuracy: 0.7083 - 612ms/epoch - 68ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.6625 - val_accuracy: 0.7361 - 430ms/epoch - 48ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.6430 - val_accuracy: 0.7361 - 421ms/epoch - 47ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0442 - accuracy: 0.9861 - val_loss: 0.6685 - val_accuracy: 0.6806 - 418ms/epoch - 46ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.7083 - 648ms/epoch - 72ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.7707 - val_accuracy: 0.7083 - 661ms/epoch - 73ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0441 - accuracy: 0.9861 - val_loss: 0.7486 - val_accuracy: 0.7361 - 538ms/epoch - 60ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0378 - accuracy: 0.9931 - val_loss: 0.7163 - val_accuracy: 0.7222 - 435ms/epoch - 48ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0409 - accuracy: 0.9931 - val_loss: 0.8721 - val_accuracy: 0.6944 - 470ms/epoch - 52ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.7559 - val_accuracy: 0.7083 - 530ms/epoch - 59ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.6501 - val_accuracy: 0.7083 - 638ms/epoch - 71ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.5911 - val_accuracy: 0.7500 - 688ms/epoch - 76ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.5418 - val_accuracy: 0.7083 - 463ms/epoch - 51ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0406 - accuracy: 0.9861 - val_loss: 0.5507 - val_accuracy: 0.7639 - 420ms/epoch - 47ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.5614 - val_accuracy: 0.7083 - 418ms/epoch - 46ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.5670 - val_accuracy: 0.7361 - 549ms/epoch - 61ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.5843 - val_accuracy: 0.7500 - 666ms/epoch - 74ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.5644 - val_accuracy: 0.6806 - 572ms/epoch - 64ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0278 - accuracy: 0.9931 - val_loss: 0.5699 - val_accuracy: 0.7500 - 419ms/epoch - 47ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.5630 - val_accuracy: 0.7500 - 415ms/epoch - 46ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.5917 - val_accuracy: 0.7500 - 426ms/epoch - 47ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.7421 - val_accuracy: 0.6528 - 641ms/epoch - 71ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0937 - accuracy: 0.9792 - val_loss: 0.8913 - val_accuracy: 0.7222 - 646ms/epoch - 72ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0665 - accuracy: 0.9861 - val_loss: 0.7136 - val_accuracy: 0.7083 - 534ms/epoch - 59ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0463 - accuracy: 0.9931 - val_loss: 0.6833 - val_accuracy: 0.7500 - 450ms/epoch - 50ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.6581 - val_accuracy: 0.7361 - 423ms/epoch - 47ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.6411 - val_accuracy: 0.7083 - 442ms/epoch - 49ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0377 - accuracy: 0.9931 - val_loss: 0.7421 - val_accuracy: 0.7639 - 636ms/epoch - 71ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.7849 - val_accuracy: 0.6944 - 674ms/epoch - 75ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.6660 - val_accuracy: 0.6944 - 444ms/epoch - 49ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.6670 - val_accuracy: 0.7083 - 418ms/epoch - 46ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.6521 - val_accuracy: 0.7222 - 417ms/epoch - 46ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.6951 - val_accuracy: 0.7083 - 476ms/epoch - 53ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.6633 - val_accuracy: 0.7361 - 658ms/epoch - 73ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.6593 - val_accuracy: 0.7500 - 658ms/epoch - 73ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.7110 - val_accuracy: 0.6806 - 431ms/epoch - 48ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.6876 - val_accuracy: 0.7639 - 439ms/epoch - 49ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.7293 - val_accuracy: 0.6806 - 462ms/epoch - 51ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.6030 - val_accuracy: 0.7500 - 596ms/epoch - 66ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0277 - accuracy: 0.9931 - val_loss: 0.6685 - val_accuracy: 0.6944 - 636ms/epoch - 71ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.6724 - val_accuracy: 0.6806 - 587ms/epoch - 65ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.6104 - val_accuracy: 0.7083 - 438ms/epoch - 49ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.7975 - val_accuracy: 0.6944 - 413ms/epoch - 46ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.6286 - val_accuracy: 0.7083 - 427ms/epoch - 47ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0285 - accuracy: 0.9931 - val_loss: 0.6984 - val_accuracy: 0.7361 - 653ms/epoch - 73ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.6523 - val_accuracy: 0.7083 - 646ms/epoch - 72ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.6942 - val_accuracy: 0.6944 - 484ms/epoch - 54ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0452 - accuracy: 0.9931 - val_loss: 0.8112 - val_accuracy: 0.6667 - 427ms/epoch - 47ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.7283 - val_accuracy: 0.7222 - 442ms/epoch - 49ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.7429 - val_accuracy: 0.6944 - 431ms/epoch - 48ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.7378 - val_accuracy: 0.7361 - 642ms/epoch - 71ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.6527 - val_accuracy: 0.7361 - 657ms/epoch - 73ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.7029 - val_accuracy: 0.6806 - 477ms/epoch - 53ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.5342 - val_accuracy: 0.7639 - 428ms/epoch - 48ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.5916 - val_accuracy: 0.7639 - 415ms/epoch - 46ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.5731 - val_accuracy: 0.7361 - 527ms/epoch - 59ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.8039 - val_accuracy: 0.6944 - 660ms/epoch - 73ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0282 - accuracy: 0.9931 - val_loss: 0.5985 - val_accuracy: 0.7361 - 651ms/epoch - 72ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0185 - accuracy: 0.9931 - val_loss: 0.6490 - val_accuracy: 0.7083 - 422ms/epoch - 47ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.7222 - 421ms/epoch - 47ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.6008 - val_accuracy: 0.7083 - 429ms/epoch - 48ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0228 - accuracy: 0.9931 - val_loss: 0.8935 - val_accuracy: 0.6528 - 646ms/epoch - 72ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.6284 - val_accuracy: 0.7083 - 637ms/epoch - 71ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.5481 - val_accuracy: 0.7361 - 523ms/epoch - 58ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5458 - val_accuracy: 0.7361 - 448ms/epoch - 50ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.5939 - val_accuracy: 0.7500 - 448ms/epoch - 50ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.6245 - val_accuracy: 0.7222 - 452ms/epoch - 50ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.6279 - val_accuracy: 0.7361 - 629ms/epoch - 70ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.7778 - 677ms/epoch - 75ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0271 - accuracy: 0.9931 - val_loss: 0.5511 - val_accuracy: 0.7500 - 471ms/epoch - 52ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.6079 - val_accuracy: 0.8056 - 426ms/epoch - 47ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0546 - accuracy: 0.9931 - val_loss: 0.7577 - val_accuracy: 0.6528 - 415ms/epoch - 46ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0738 - accuracy: 0.9722 - val_loss: 1.0152 - val_accuracy: 0.6528 - 549ms/epoch - 61ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0376 - accuracy: 0.9931 - val_loss: 1.0027 - val_accuracy: 0.6111 - 643ms/epoch - 71ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0327 - accuracy: 0.9861 - val_loss: 0.7403 - val_accuracy: 0.7222 - 652ms/epoch - 72ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.6840 - val_accuracy: 0.7361 - 437ms/epoch - 49ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0250 - accuracy: 0.9931 - val_loss: 0.7894 - val_accuracy: 0.7083 - 439ms/epoch - 49ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.9315 - val_accuracy: 0.6667 - 415ms/epoch - 46ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.7223 - val_accuracy: 0.7500 - 556ms/epoch - 62ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.8959 - val_accuracy: 0.6528 - 677ms/epoch - 75ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.9590 - val_accuracy: 0.6806 - 556ms/epoch - 62ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.8189 - val_accuracy: 0.6806 - 420ms/epoch - 47ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.7793 - val_accuracy: 0.7222 - 412ms/epoch - 46ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.6667 - val_accuracy: 0.6944 - 417ms/epoch - 46ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.6447 - val_accuracy: 0.6944 - 594ms/epoch - 66ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0260 - accuracy: 0.9931 - val_loss: 1.0688 - val_accuracy: 0.6250 - 735ms/epoch - 82ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0351 - accuracy: 0.9931 - val_loss: 0.9090 - val_accuracy: 0.6528 - 510ms/epoch - 57ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.7122 - val_accuracy: 0.7083 - 427ms/epoch - 47ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.7948 - val_accuracy: 0.6944 - 431ms/epoch - 48ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.7259 - val_accuracy: 0.6806 - 500ms/epoch - 56ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.7871 - val_accuracy: 0.6806 - 651ms/epoch - 72ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.8245 - val_accuracy: 0.7083 - 644ms/epoch - 72ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.6448 - val_accuracy: 0.7361 - 488ms/epoch - 54ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.6806 - 421ms/epoch - 47ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6666 - val_accuracy: 0.7222 - 416ms/epoch - 46ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.6464 - val_accuracy: 0.7361 - 529ms/epoch - 59ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.7806 - val_accuracy: 0.7361 - 664ms/epoch - 74ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0169 - accuracy: 0.9931 - val_loss: 0.6922 - val_accuracy: 0.7222 - 587ms/epoch - 65ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.7083 - 422ms/epoch - 47ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.6667 - 424ms/epoch - 47ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.6528 - 434ms/epoch - 48ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.6096 - val_accuracy: 0.6944 - 573ms/epoch - 64ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.6935 - val_accuracy: 0.7083 - 642ms/epoch - 71ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0229 - accuracy: 0.9861 - val_loss: 0.7903 - val_accuracy: 0.7222 - 567ms/epoch - 63ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.7049 - val_accuracy: 0.6944 - 448ms/epoch - 50ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.6687 - val_accuracy: 0.7222 - 414ms/epoch - 46ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.7083 - 419ms/epoch - 47ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.9883 - val_accuracy: 0.7083 - 640ms/epoch - 71ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.6933 - val_accuracy: 0.7083 - 663ms/epoch - 74ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.8080 - val_accuracy: 0.6944 - 528ms/epoch - 59ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.9701 - val_accuracy: 0.6667 - 462ms/epoch - 51ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.9803 - val_accuracy: 0.6528 - 415ms/epoch - 46ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.7866 - val_accuracy: 0.6944 - 524ms/epoch - 58ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.6585 - val_accuracy: 0.7222 - 636ms/epoch - 71ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.6543 - val_accuracy: 0.7222 - 641ms/epoch - 71ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.6579 - val_accuracy: 0.7083 - 439ms/epoch - 49ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.6032 - val_accuracy: 0.7778 - 454ms/epoch - 50ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.6622 - val_accuracy: 0.7222 - 421ms/epoch - 47ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.6009 - val_accuracy: 0.7500 - 514ms/epoch - 57ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0329 - accuracy: 0.9931 - val_loss: 0.6305 - val_accuracy: 0.7222 - 641ms/epoch - 71ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.8413 - val_accuracy: 0.6944 - 621ms/epoch - 69ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.6106 - val_accuracy: 0.6806 - 425ms/epoch - 47ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.7222 - 439ms/epoch - 49ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.6645 - val_accuracy: 0.6806 - 444ms/epoch - 49ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.6333 - val_accuracy: 0.7500 - 708ms/epoch - 79ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.6409 - val_accuracy: 0.6806 - 637ms/epoch - 71ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.7559 - val_accuracy: 0.6528 - 512ms/epoch - 57ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.6667 - 445ms/epoch - 49ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.0793 - val_accuracy: 0.6806 - 434ms/epoch - 48ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.6667 - 482ms/epoch - 54ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.6051 - val_accuracy: 0.7778 - 630ms/epoch - 70ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0174 - accuracy: 0.9931 - val_loss: 0.5807 - val_accuracy: 0.7500 - 666ms/epoch - 74ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.8433 - val_accuracy: 0.6667 - 427ms/epoch - 47ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.6747 - val_accuracy: 0.7500 - 420ms/epoch - 47ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.6972 - val_accuracy: 0.6944 - 456ms/epoch - 51ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.9301 - val_accuracy: 0.6250 - 512ms/epoch - 57ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.9898 - val_accuracy: 0.6667 - 661ms/epoch - 73ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.8261 - val_accuracy: 0.6667 - 613ms/epoch - 68ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0177 - accuracy: 0.9931 - val_loss: 0.6238 - val_accuracy: 0.7222 - 421ms/epoch - 47ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.7029 - val_accuracy: 0.7361 - 438ms/epoch - 49ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0254 - accuracy: 0.9861 - val_loss: 0.7015 - val_accuracy: 0.7222 - 429ms/epoch - 48ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0261 - accuracy: 0.9931 - val_loss: 1.1908 - val_accuracy: 0.6389 - 595ms/epoch - 66ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0332 - accuracy: 0.9861 - val_loss: 0.7200 - val_accuracy: 0.6806 - 644ms/epoch - 72ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.1594 - val_accuracy: 0.6528 - 575ms/epoch - 64ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.7916 - val_accuracy: 0.6806 - 433ms/epoch - 48ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.6787 - val_accuracy: 0.6944 - 418ms/epoch - 46ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.7222 - 417ms/epoch - 46ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.7916 - val_accuracy: 0.7361 - 675ms/epoch - 75ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.7377 - val_accuracy: 0.7222 - 746ms/epoch - 83ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.7170 - val_accuracy: 0.7083 - 449ms/epoch - 50ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0204 - accuracy: 0.9931 - val_loss: 1.1425 - val_accuracy: 0.6944 - 415ms/epoch - 46ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.7512 - val_accuracy: 0.7083 - 414ms/epoch - 46ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.7655 - val_accuracy: 0.7222 - 463ms/epoch - 51ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.0782 - val_accuracy: 0.6111 - 666ms/epoch - 74ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.7361 - 674ms/epoch - 75ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.7302 - val_accuracy: 0.7222 - 418ms/epoch - 46ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.6493 - val_accuracy: 0.7222 - 422ms/epoch - 47ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.53284
# 9/9 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.6900 - val_accuracy: 0.7361 - 447ms/epoch - 50ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9147 - val_accuracy: 0.6528 - 661ms/epoch - 73ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.53284
# 9/9 - 1s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.2647 - val_accuracy: 0.6250 - 655ms/epoch - 73ms/step
# 3/3 [==============================] - 0s 18ms/step
# Classification accuracy: 0.833333

# %%
X_test[0].shape
# Out:
# (60, 151, 1)

# %%
###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 11ms/step
# Classification accuracy: 0.888889

# %%
model.predict(X_test).argmax(axis = -1)
# Out:
# 3/3 [==============================] - 0s 15ms/step
# array([3, 1, 2, 1, 3, 1, 2, 1, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2,
#        0, 3, 1, 2, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 0, 2, 1, 2, 1,
#        2, 0, 2, 1, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        0, 3, 0, 2, 0, 3], dtype=int64)

# %%
Y_test.argmax(axis=-1)
# Out:
# array([3, 1, 2, 0, 3, 1, 2, 0, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2,
#        0, 3, 1, 2, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        2, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1,
#        0, 3, 1, 2, 0, 3], dtype=int64)
