# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# %%
def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)

# %%
## trainer 

"""
 Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data
 from a four-class classification task, using the sample dataset provided in
 the MNE [1, 2] package:
     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data
   
 The four classes used from this dataset are:
     LA: Left-ear auditory stimulation
     RA: Right-ear auditory stimulation
     LV: Left visual field stimulation
     RV: Right visual field stimulation

 The code to process, filter and epoch the data are originally from Alexandre
 Barachant's PyRiemann [3] package, released under the BSD 3-clause. A copy of 
 the BSD 3-clause license has been provided together with this software to 
 comply with software licensing requirements. 
 
 When you first run this script, MNE will download the dataset and prompt you
 to confirm the download location (defaults to ~/mne_data). Follow the prompts
 to continue. The dataset size is approx. 1.5GB download. 
 
 For comparative purposes you can also compare EEGNet performance to using 
 Riemannian geometric approaches with xDAWN spatial filtering [4-8] using 
 PyRiemann (code provided below).

 [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,
     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, 
     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.

 [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, 
     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data 
     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.

 [3] https://github.com/alexandrebarachant/pyRiemann. 

 [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"
     arXiv:1409.0107. link

 [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer 
     Interface Based on Riemannian Geometry", arXiv: 1310.8115.

 [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian 
     distance for BCI applications," in 2011 5th International IEEE/EMBS 
     Conference on Neural Engineering (NER), 2011, 348-351.

 [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass 
     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE 
     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.

 [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of 
     covariance matrices using a Riemannian-based kernel for BCI applications“, 
     in NeuroComputing, vol. 112, p. 172-178, 2013.


 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw.fif'
event_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB
#
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples, dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint1.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 1.38625, saving model to checkpoint1.h5
# 9/9 - 2s - loss: 1.3985 - accuracy: 0.2639 - val_loss: 1.3863 - val_accuracy: 0.2500 - 2s/epoch - 184ms/step
# Epoch 2/300
# c:\Users\sandr\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 1.38625 to 1.38620, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.3676 - accuracy: 0.2639 - val_loss: 1.3862 - val_accuracy: 0.2500 - 376ms/epoch - 42ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 1.38620
# 9/9 - 0s - loss: 1.3707 - accuracy: 0.3472 - val_loss: 1.3862 - val_accuracy: 0.2500 - 337ms/epoch - 37ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 1.38620 to 1.38617, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.3561 - accuracy: 0.3542 - val_loss: 1.3862 - val_accuracy: 0.2500 - 373ms/epoch - 41ms/step
# Epoch 5/300
#
# Epoch 5: val_loss improved from 1.38617 to 1.38614, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.3459 - accuracy: 0.3472 - val_loss: 1.3861 - val_accuracy: 0.2500 - 407ms/epoch - 45ms/step
# Epoch 6/300
#
# Epoch 6: val_loss improved from 1.38614 to 1.38611, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.3329 - accuracy: 0.4167 - val_loss: 1.3861 - val_accuracy: 0.2500 - 379ms/epoch - 42ms/step
# Epoch 7/300
#
# Epoch 7: val_loss improved from 1.38611 to 1.38606, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.3119 - accuracy: 0.4792 - val_loss: 1.3861 - val_accuracy: 0.2500 - 411ms/epoch - 46ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.38606 to 1.38592, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.2923 - accuracy: 0.4583 - val_loss: 1.3859 - val_accuracy: 0.2500 - 400ms/epoch - 44ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.38592 to 1.38579, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.2516 - accuracy: 0.4861 - val_loss: 1.3858 - val_accuracy: 0.3611 - 407ms/epoch - 45ms/step
# Epoch 10/300
#
# Epoch 10: val_loss improved from 1.38579 to 1.38557, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.2155 - accuracy: 0.5069 - val_loss: 1.3856 - val_accuracy: 0.2917 - 344ms/epoch - 38ms/step
# Epoch 11/300
#
# Epoch 11: val_loss improved from 1.38557 to 1.38535, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.1947 - accuracy: 0.4861 - val_loss: 1.3853 - val_accuracy: 0.2917 - 367ms/epoch - 41ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.38535 to 1.38502, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.1558 - accuracy: 0.4514 - val_loss: 1.3850 - val_accuracy: 0.2639 - 338ms/epoch - 38ms/step
# Epoch 13/300
#
# Epoch 13: val_loss improved from 1.38502 to 1.38466, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.1367 - accuracy: 0.4792 - val_loss: 1.3847 - val_accuracy: 0.2639 - 399ms/epoch - 44ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 1.38466 to 1.38424, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.1074 - accuracy: 0.5486 - val_loss: 1.3842 - val_accuracy: 0.2639 - 343ms/epoch - 38ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 1.38424 to 1.38373, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0710 - accuracy: 0.5139 - val_loss: 1.3837 - val_accuracy: 0.2639 - 403ms/epoch - 45ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.38373 to 1.38322, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0695 - accuracy: 0.5278 - val_loss: 1.3832 - val_accuracy: 0.2639 - 358ms/epoch - 40ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 1.38322 to 1.38273, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0611 - accuracy: 0.5278 - val_loss: 1.3827 - val_accuracy: 0.2778 - 378ms/epoch - 42ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 1.38273 to 1.38207, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0562 - accuracy: 0.5278 - val_loss: 1.3821 - val_accuracy: 0.2778 - 332ms/epoch - 37ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 1.38207 to 1.38134, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0375 - accuracy: 0.4861 - val_loss: 1.3813 - val_accuracy: 0.2639 - 388ms/epoch - 43ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 1.38134 to 1.38048, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0451 - accuracy: 0.5556 - val_loss: 1.3805 - val_accuracy: 0.2500 - 345ms/epoch - 38ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 1.38048 to 1.37956, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0334 - accuracy: 0.5278 - val_loss: 1.3796 - val_accuracy: 0.2639 - 356ms/epoch - 40ms/step
# Epoch 22/300
#
# Epoch 22: val_loss improved from 1.37956 to 1.37865, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0384 - accuracy: 0.5556 - val_loss: 1.3786 - val_accuracy: 0.2639 - 411ms/epoch - 46ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 1.37865 to 1.37766, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0197 - accuracy: 0.5486 - val_loss: 1.3777 - val_accuracy: 0.2639 - 353ms/epoch - 39ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 1.37766 to 1.37648, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0183 - accuracy: 0.5139 - val_loss: 1.3765 - val_accuracy: 0.2778 - 400ms/epoch - 44ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 1.37648 to 1.37567, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0188 - accuracy: 0.5069 - val_loss: 1.3757 - val_accuracy: 0.2917 - 356ms/epoch - 40ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 1.37567 to 1.37460, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0451 - accuracy: 0.5417 - val_loss: 1.3746 - val_accuracy: 0.2917 - 382ms/epoch - 42ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 1.37460 to 1.37280, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0136 - accuracy: 0.5694 - val_loss: 1.3728 - val_accuracy: 0.2917 - 341ms/epoch - 38ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 1.37280 to 1.37125, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9937 - accuracy: 0.5486 - val_loss: 1.3713 - val_accuracy: 0.3056 - 440ms/epoch - 49ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 1.37125 to 1.36871, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9883 - accuracy: 0.5417 - val_loss: 1.3687 - val_accuracy: 0.3194 - 333ms/epoch - 37ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 1.36871 to 1.36684, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9819 - accuracy: 0.5556 - val_loss: 1.3668 - val_accuracy: 0.3056 - 373ms/epoch - 41ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 1.36684 to 1.36485, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9921 - accuracy: 0.5139 - val_loss: 1.3649 - val_accuracy: 0.2917 - 354ms/epoch - 39ms/step
# Epoch 32/300
#
# Epoch 32: val_loss improved from 1.36485 to 1.36245, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0032 - accuracy: 0.5417 - val_loss: 1.3625 - val_accuracy: 0.3194 - 389ms/epoch - 43ms/step
# Epoch 33/300
#
# Epoch 33: val_loss improved from 1.36245 to 1.36013, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9859 - accuracy: 0.5764 - val_loss: 1.3601 - val_accuracy: 0.3194 - 341ms/epoch - 38ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 1.36013 to 1.35703, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9792 - accuracy: 0.5694 - val_loss: 1.3570 - val_accuracy: 0.3750 - 345ms/epoch - 38ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 1.35703 to 1.35461, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9850 - accuracy: 0.5833 - val_loss: 1.3546 - val_accuracy: 0.3750 - 398ms/epoch - 44ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 1.35461 to 1.35144, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9671 - accuracy: 0.5556 - val_loss: 1.3514 - val_accuracy: 0.4028 - 396ms/epoch - 44ms/step
# Epoch 37/300
#
# Epoch 37: val_loss improved from 1.35144 to 1.34820, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9814 - accuracy: 0.5347 - val_loss: 1.3482 - val_accuracy: 0.4167 - 396ms/epoch - 44ms/step
# Epoch 38/300
#
# Epoch 38: val_loss improved from 1.34820 to 1.34283, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9675 - accuracy: 0.5347 - val_loss: 1.3428 - val_accuracy: 0.4028 - 369ms/epoch - 41ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 1.34283 to 1.33897, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9583 - accuracy: 0.5694 - val_loss: 1.3390 - val_accuracy: 0.4028 - 370ms/epoch - 41ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 1.33897 to 1.33509, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9389 - accuracy: 0.5764 - val_loss: 1.3351 - val_accuracy: 0.3889 - 337ms/epoch - 37ms/step
# Epoch 41/300
#
# Epoch 41: val_loss improved from 1.33509 to 1.33088, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9561 - accuracy: 0.5556 - val_loss: 1.3309 - val_accuracy: 0.3750 - 374ms/epoch - 42ms/step
# Epoch 42/300
#
# Epoch 42: val_loss improved from 1.33088 to 1.32593, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9457 - accuracy: 0.5625 - val_loss: 1.3259 - val_accuracy: 0.3889 - 338ms/epoch - 38ms/step
# Epoch 43/300
#
# Epoch 43: val_loss improved from 1.32593 to 1.32148, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9396 - accuracy: 0.6319 - val_loss: 1.3215 - val_accuracy: 0.3750 - 360ms/epoch - 40ms/step
# Epoch 44/300
#
# Epoch 44: val_loss improved from 1.32148 to 1.31762, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9330 - accuracy: 0.6319 - val_loss: 1.3176 - val_accuracy: 0.3750 - 339ms/epoch - 38ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 1.31762 to 1.30987, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9386 - accuracy: 0.5417 - val_loss: 1.3099 - val_accuracy: 0.3889 - 425ms/epoch - 47ms/step
# Epoch 46/300
#
# Epoch 46: val_loss improved from 1.30987 to 1.30638, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9107 - accuracy: 0.6111 - val_loss: 1.3064 - val_accuracy: 0.4167 - 359ms/epoch - 40ms/step
# Epoch 47/300
#
# Epoch 47: val_loss improved from 1.30638 to 1.30014, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9422 - accuracy: 0.6319 - val_loss: 1.3001 - val_accuracy: 0.4028 - 399ms/epoch - 44ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 1.30014 to 1.29328, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9190 - accuracy: 0.6111 - val_loss: 1.2933 - val_accuracy: 0.4167 - 358ms/epoch - 40ms/step
# Epoch 49/300
#
# Epoch 49: val_loss improved from 1.29328 to 1.29032, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9005 - accuracy: 0.6528 - val_loss: 1.2903 - val_accuracy: 0.3750 - 346ms/epoch - 38ms/step
# Epoch 50/300
#
# Epoch 50: val_loss improved from 1.29032 to 1.28293, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8922 - accuracy: 0.6042 - val_loss: 1.2829 - val_accuracy: 0.3889 - 401ms/epoch - 45ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 1.28293 to 1.26829, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8946 - accuracy: 0.5972 - val_loss: 1.2683 - val_accuracy: 0.4028 - 367ms/epoch - 41ms/step
# Epoch 52/300
#
# Epoch 52: val_loss improved from 1.26829 to 1.26720, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8940 - accuracy: 0.6181 - val_loss: 1.2672 - val_accuracy: 0.4444 - 367ms/epoch - 41ms/step
# Epoch 53/300
#
# Epoch 53: val_loss improved from 1.26720 to 1.24681, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8749 - accuracy: 0.6250 - val_loss: 1.2468 - val_accuracy: 0.3750 - 381ms/epoch - 42ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 1.24681 to 1.24482, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8565 - accuracy: 0.6389 - val_loss: 1.2448 - val_accuracy: 0.4167 - 342ms/epoch - 38ms/step
# Epoch 55/300
#
# Epoch 55: val_loss improved from 1.24482 to 1.23206, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8603 - accuracy: 0.6806 - val_loss: 1.2321 - val_accuracy: 0.4028 - 396ms/epoch - 44ms/step
# Epoch 56/300
#
# Epoch 56: val_loss improved from 1.23206 to 1.23158, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8590 - accuracy: 0.6806 - val_loss: 1.2316 - val_accuracy: 0.4583 - 337ms/epoch - 37ms/step
# Epoch 57/300
#
# Epoch 57: val_loss improved from 1.23158 to 1.21066, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8632 - accuracy: 0.6736 - val_loss: 1.2107 - val_accuracy: 0.4583 - 376ms/epoch - 42ms/step
# Epoch 58/300
#
# Epoch 58: val_loss improved from 1.21066 to 1.20640, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8454 - accuracy: 0.6667 - val_loss: 1.2064 - val_accuracy: 0.4861 - 389ms/epoch - 43ms/step
# Epoch 59/300
#
# Epoch 59: val_loss improved from 1.20640 to 1.19005, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8469 - accuracy: 0.6806 - val_loss: 1.1901 - val_accuracy: 0.4583 - 380ms/epoch - 42ms/step
# Epoch 60/300
#
# Epoch 60: val_loss improved from 1.19005 to 1.18148, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8274 - accuracy: 0.7222 - val_loss: 1.1815 - val_accuracy: 0.4583 - 365ms/epoch - 41ms/step
# Epoch 61/300
#
# Epoch 61: val_loss improved from 1.18148 to 1.17339, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8559 - accuracy: 0.6736 - val_loss: 1.1734 - val_accuracy: 0.4167 - 338ms/epoch - 38ms/step
# Epoch 62/300
#
# Epoch 62: val_loss improved from 1.17339 to 1.16783, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8283 - accuracy: 0.7014 - val_loss: 1.1678 - val_accuracy: 0.4028 - 361ms/epoch - 40ms/step
# Epoch 63/300
#
# Epoch 63: val_loss improved from 1.16783 to 1.16103, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8261 - accuracy: 0.6806 - val_loss: 1.1610 - val_accuracy: 0.4306 - 398ms/epoch - 44ms/step
# Epoch 64/300
#
# Epoch 64: val_loss improved from 1.16103 to 1.14658, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8217 - accuracy: 0.6806 - val_loss: 1.1466 - val_accuracy: 0.4861 - 356ms/epoch - 40ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 1.14658
# 9/9 - 0s - loss: 0.8408 - accuracy: 0.6944 - val_loss: 1.1483 - val_accuracy: 0.4167 - 380ms/epoch - 42ms/step
# Epoch 66/300
#
# Epoch 66: val_loss improved from 1.14658 to 1.11482, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8165 - accuracy: 0.6944 - val_loss: 1.1148 - val_accuracy: 0.5139 - 432ms/epoch - 48ms/step
# Epoch 67/300
#
# Epoch 67: val_loss improved from 1.11482 to 1.10083, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8231 - accuracy: 0.6806 - val_loss: 1.1008 - val_accuracy: 0.5278 - 379ms/epoch - 42ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 1.10083
# 9/9 - 0s - loss: 0.8557 - accuracy: 0.6528 - val_loss: 1.1080 - val_accuracy: 0.4861 - 333ms/epoch - 37ms/step
# Epoch 69/300
#
# Epoch 69: val_loss improved from 1.10083 to 1.08343, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7982 - accuracy: 0.7431 - val_loss: 1.0834 - val_accuracy: 0.5000 - 382ms/epoch - 42ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 1.08343
# 9/9 - 0s - loss: 0.8133 - accuracy: 0.6806 - val_loss: 1.0865 - val_accuracy: 0.5417 - 352ms/epoch - 39ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 1.08343 to 1.06988, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7884 - accuracy: 0.7153 - val_loss: 1.0699 - val_accuracy: 0.5694 - 374ms/epoch - 42ms/step
# Epoch 72/300
#
# Epoch 72: val_loss improved from 1.06988 to 1.06308, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.8061 - accuracy: 0.7292 - val_loss: 1.0631 - val_accuracy: 0.5833 - 387ms/epoch - 43ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 1.06308
# 9/9 - 0s - loss: 0.7419 - accuracy: 0.7569 - val_loss: 1.0753 - val_accuracy: 0.5417 - 324ms/epoch - 36ms/step
# Epoch 74/300
#
# Epoch 74: val_loss improved from 1.06308 to 1.05816, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7490 - accuracy: 0.7569 - val_loss: 1.0582 - val_accuracy: 0.5556 - 361ms/epoch - 40ms/step
# Epoch 75/300
#
# Epoch 75: val_loss improved from 1.05816 to 1.05281, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7639 - accuracy: 0.7708 - val_loss: 1.0528 - val_accuracy: 0.5556 - 396ms/epoch - 44ms/step
# Epoch 76/300
#
# Epoch 76: val_loss improved from 1.05281 to 1.04281, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7481 - accuracy: 0.7639 - val_loss: 1.0428 - val_accuracy: 0.5417 - 373ms/epoch - 41ms/step
# Epoch 77/300
#
# Epoch 77: val_loss improved from 1.04281 to 1.01577, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7581 - accuracy: 0.7917 - val_loss: 1.0158 - val_accuracy: 0.5417 - 403ms/epoch - 45ms/step
# Epoch 78/300
#
# Epoch 78: val_loss improved from 1.01577 to 1.00919, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7842 - accuracy: 0.7500 - val_loss: 1.0092 - val_accuracy: 0.6111 - 343ms/epoch - 38ms/step
# Epoch 79/300
#
# Epoch 79: val_loss improved from 1.00919 to 1.00425, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7426 - accuracy: 0.8056 - val_loss: 1.0043 - val_accuracy: 0.6528 - 412ms/epoch - 46ms/step
# Epoch 80/300
#
# Epoch 80: val_loss improved from 1.00425 to 0.98762, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7657 - accuracy: 0.7500 - val_loss: 0.9876 - val_accuracy: 0.5972 - 375ms/epoch - 42ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.98762
# 9/9 - 0s - loss: 0.7652 - accuracy: 0.7639 - val_loss: 0.9917 - val_accuracy: 0.6389 - 363ms/epoch - 40ms/step
# Epoch 82/300
#
# Epoch 82: val_loss improved from 0.98762 to 0.97364, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7316 - accuracy: 0.7778 - val_loss: 0.9736 - val_accuracy: 0.5972 - 346ms/epoch - 38ms/step
# Epoch 83/300
#
# Epoch 83: val_loss improved from 0.97364 to 0.95387, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7424 - accuracy: 0.7639 - val_loss: 0.9539 - val_accuracy: 0.6111 - 366ms/epoch - 41ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.95387
# 9/9 - 0s - loss: 0.7572 - accuracy: 0.7708 - val_loss: 0.9583 - val_accuracy: 0.5833 - 320ms/epoch - 36ms/step
# Epoch 85/300
#
# Epoch 85: val_loss improved from 0.95387 to 0.95104, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7349 - accuracy: 0.7500 - val_loss: 0.9510 - val_accuracy: 0.6389 - 357ms/epoch - 40ms/step
# Epoch 86/300
#
# Epoch 86: val_loss improved from 0.95104 to 0.91892, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.6874 - accuracy: 0.8125 - val_loss: 0.9189 - val_accuracy: 0.6250 - 422ms/epoch - 47ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.91892
# 9/9 - 0s - loss: 0.7015 - accuracy: 0.7986 - val_loss: 0.9346 - val_accuracy: 0.6389 - 296ms/epoch - 33ms/step
# Epoch 88/300
#
# Epoch 88: val_loss improved from 0.91892 to 0.89831, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7214 - accuracy: 0.7986 - val_loss: 0.8983 - val_accuracy: 0.6389 - 350ms/epoch - 39ms/step
# Epoch 89/300
#
# Epoch 89: val_loss improved from 0.89831 to 0.88626, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7220 - accuracy: 0.7292 - val_loss: 0.8863 - val_accuracy: 0.6389 - 383ms/epoch - 43ms/step
# Epoch 90/300
#
# Epoch 90: val_loss improved from 0.88626 to 0.88247, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7221 - accuracy: 0.7986 - val_loss: 0.8825 - val_accuracy: 0.6944 - 374ms/epoch - 42ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.88247
# 9/9 - 0s - loss: 0.6668 - accuracy: 0.8333 - val_loss: 0.9439 - val_accuracy: 0.6389 - 325ms/epoch - 36ms/step
# Epoch 92/300
#
# Epoch 92: val_loss improved from 0.88247 to 0.86938, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7012 - accuracy: 0.8542 - val_loss: 0.8694 - val_accuracy: 0.7083 - 336ms/epoch - 37ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.86938
# 9/9 - 0s - loss: 0.6868 - accuracy: 0.8403 - val_loss: 0.8906 - val_accuracy: 0.6944 - 365ms/epoch - 41ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.86938
# 9/9 - 0s - loss: 0.6691 - accuracy: 0.8333 - val_loss: 0.8740 - val_accuracy: 0.6528 - 326ms/epoch - 36ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.86938
# 9/9 - 0s - loss: 0.6738 - accuracy: 0.8194 - val_loss: 0.8838 - val_accuracy: 0.6806 - 332ms/epoch - 37ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.86938
# 9/9 - 0s - loss: 0.6412 - accuracy: 0.8056 - val_loss: 0.8939 - val_accuracy: 0.6111 - 351ms/epoch - 39ms/step
# Epoch 97/300
#
# Epoch 97: val_loss improved from 0.86938 to 0.86600, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7232 - accuracy: 0.7778 - val_loss: 0.8660 - val_accuracy: 0.6806 - 367ms/epoch - 41ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.86600
# 9/9 - 0s - loss: 0.6517 - accuracy: 0.8542 - val_loss: 0.8667 - val_accuracy: 0.5972 - 325ms/epoch - 36ms/step
# Epoch 99/300
#
# Epoch 99: val_loss improved from 0.86600 to 0.82387, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.6569 - accuracy: 0.8542 - val_loss: 0.8239 - val_accuracy: 0.6528 - 365ms/epoch - 41ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.82387
# 9/9 - 0s - loss: 0.6491 - accuracy: 0.7917 - val_loss: 0.8776 - val_accuracy: 0.7361 - 330ms/epoch - 37ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.82387
# 9/9 - 0s - loss: 0.6403 - accuracy: 0.8194 - val_loss: 0.8362 - val_accuracy: 0.6667 - 321ms/epoch - 36ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.82387
# 9/9 - 0s - loss: 0.6833 - accuracy: 0.7917 - val_loss: 0.8775 - val_accuracy: 0.6528 - 307ms/epoch - 34ms/step
# Epoch 103/300
#
# Epoch 103: val_loss improved from 0.82387 to 0.81315, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.6748 - accuracy: 0.8125 - val_loss: 0.8132 - val_accuracy: 0.7222 - 332ms/epoch - 37ms/step
# Epoch 104/300
#
# Epoch 104: val_loss improved from 0.81315 to 0.81258, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.6515 - accuracy: 0.8264 - val_loss: 0.8126 - val_accuracy: 0.6944 - 388ms/epoch - 43ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.81258
# 9/9 - 0s - loss: 0.6179 - accuracy: 0.8889 - val_loss: 0.8412 - val_accuracy: 0.7222 - 298ms/epoch - 33ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.81258
# 9/9 - 0s - loss: 0.6273 - accuracy: 0.8194 - val_loss: 0.8854 - val_accuracy: 0.6389 - 290ms/epoch - 32ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.81258
# 9/9 - 0s - loss: 0.6543 - accuracy: 0.7917 - val_loss: 0.8456 - val_accuracy: 0.7361 - 289ms/epoch - 32ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.81258
# 9/9 - 0s - loss: 0.6678 - accuracy: 0.8194 - val_loss: 0.8219 - val_accuracy: 0.6944 - 291ms/epoch - 32ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.81258
# 9/9 - 0s - loss: 0.6067 - accuracy: 0.8333 - val_loss: 0.8363 - val_accuracy: 0.6528 - 286ms/epoch - 32ms/step
# Epoch 110/300
#
# Epoch 110: val_loss improved from 0.81258 to 0.78426, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.6358 - accuracy: 0.8403 - val_loss: 0.7843 - val_accuracy: 0.7361 - 324ms/epoch - 36ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.5652 - accuracy: 0.9167 - val_loss: 0.7961 - val_accuracy: 0.6944 - 347ms/epoch - 39ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.6222 - accuracy: 0.8264 - val_loss: 0.8166 - val_accuracy: 0.6944 - 312ms/epoch - 35ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.5334 - accuracy: 0.8889 - val_loss: 0.7943 - val_accuracy: 0.6667 - 291ms/epoch - 32ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.5745 - accuracy: 0.8472 - val_loss: 0.8091 - val_accuracy: 0.7500 - 287ms/epoch - 32ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.5749 - accuracy: 0.8750 - val_loss: 0.8164 - val_accuracy: 0.6944 - 289ms/epoch - 32ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.78426
# 9/9 - 0s - loss: 0.5583 - accuracy: 0.8403 - val_loss: 0.8062 - val_accuracy: 0.7361 - 290ms/epoch - 32ms/step
# Epoch 117/300
#
# Epoch 117: val_loss improved from 0.78426 to 0.75118, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5845 - accuracy: 0.8611 - val_loss: 0.7512 - val_accuracy: 0.7361 - 326ms/epoch - 36ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.6079 - accuracy: 0.8333 - val_loss: 0.8069 - val_accuracy: 0.7222 - 341ms/epoch - 38ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5802 - accuracy: 0.8472 - val_loss: 0.7655 - val_accuracy: 0.7222 - 296ms/epoch - 33ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5848 - accuracy: 0.8681 - val_loss: 0.7921 - val_accuracy: 0.6944 - 312ms/epoch - 35ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5747 - accuracy: 0.8472 - val_loss: 0.7782 - val_accuracy: 0.7500 - 287ms/epoch - 32ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5893 - accuracy: 0.8472 - val_loss: 0.7867 - val_accuracy: 0.6944 - 291ms/epoch - 32ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5755 - accuracy: 0.8472 - val_loss: 0.7682 - val_accuracy: 0.7083 - 292ms/epoch - 32ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.75118
# 9/9 - 0s - loss: 0.5403 - accuracy: 0.8542 - val_loss: 0.7964 - val_accuracy: 0.6806 - 293ms/epoch - 33ms/step
# Epoch 125/300
#
# Epoch 125: val_loss improved from 0.75118 to 0.74020, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5742 - accuracy: 0.8264 - val_loss: 0.7402 - val_accuracy: 0.7639 - 332ms/epoch - 37ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5252 - accuracy: 0.8819 - val_loss: 0.7565 - val_accuracy: 0.7500 - 343ms/epoch - 38ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5487 - accuracy: 0.8611 - val_loss: 0.7713 - val_accuracy: 0.7222 - 290ms/epoch - 32ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5630 - accuracy: 0.8403 - val_loss: 0.7778 - val_accuracy: 0.6944 - 291ms/epoch - 32ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5346 - accuracy: 0.8611 - val_loss: 0.7827 - val_accuracy: 0.7083 - 301ms/epoch - 33ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5277 - accuracy: 0.8750 - val_loss: 0.7739 - val_accuracy: 0.7361 - 302ms/epoch - 34ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5559 - accuracy: 0.8403 - val_loss: 0.7516 - val_accuracy: 0.7083 - 300ms/epoch - 33ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.74020
# 9/9 - 0s - loss: 0.5577 - accuracy: 0.8264 - val_loss: 0.7474 - val_accuracy: 0.7222 - 290ms/epoch - 32ms/step
# Epoch 133/300
#
# Epoch 133: val_loss improved from 0.74020 to 0.73959, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5324 - accuracy: 0.8889 - val_loss: 0.7396 - val_accuracy: 0.7639 - 330ms/epoch - 37ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.73959
# 9/9 - 0s - loss: 0.5609 - accuracy: 0.8125 - val_loss: 0.7866 - val_accuracy: 0.7361 - 314ms/epoch - 35ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.73959
# 9/9 - 0s - loss: 0.5591 - accuracy: 0.8611 - val_loss: 0.7705 - val_accuracy: 0.6389 - 290ms/epoch - 32ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.73959
# 9/9 - 0s - loss: 0.5077 - accuracy: 0.8889 - val_loss: 0.7876 - val_accuracy: 0.7083 - 287ms/epoch - 32ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.73959
# 9/9 - 0s - loss: 0.5200 - accuracy: 0.8958 - val_loss: 0.7665 - val_accuracy: 0.7083 - 293ms/epoch - 33ms/step
# Epoch 138/300
#
# Epoch 138: val_loss improved from 0.73959 to 0.73734, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5479 - accuracy: 0.8542 - val_loss: 0.7373 - val_accuracy: 0.7500 - 326ms/epoch - 36ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.73734
# 9/9 - 0s - loss: 0.5266 - accuracy: 0.8542 - val_loss: 0.8008 - val_accuracy: 0.6944 - 390ms/epoch - 43ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.73734
# 9/9 - 0s - loss: 0.5012 - accuracy: 0.8750 - val_loss: 0.7826 - val_accuracy: 0.7361 - 294ms/epoch - 33ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.73734
# 9/9 - 0s - loss: 0.5295 - accuracy: 0.8611 - val_loss: 0.7813 - val_accuracy: 0.6806 - 284ms/epoch - 32ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.73734
# 9/9 - 0s - loss: 0.5320 - accuracy: 0.8750 - val_loss: 0.7445 - val_accuracy: 0.7500 - 291ms/epoch - 32ms/step
# Epoch 143/300
#
# Epoch 143: val_loss improved from 0.73734 to 0.72786, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5446 - accuracy: 0.8681 - val_loss: 0.7279 - val_accuracy: 0.7222 - 338ms/epoch - 38ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.72786
# 9/9 - 0s - loss: 0.5048 - accuracy: 0.8681 - val_loss: 0.7430 - val_accuracy: 0.7917 - 285ms/epoch - 32ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.72786
# 9/9 - 0s - loss: 0.4754 - accuracy: 0.9167 - val_loss: 0.7621 - val_accuracy: 0.7639 - 301ms/epoch - 33ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.72786
# 9/9 - 0s - loss: 0.4991 - accuracy: 0.8819 - val_loss: 0.7300 - val_accuracy: 0.7917 - 291ms/epoch - 32ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.72786
# 9/9 - 0s - loss: 0.5043 - accuracy: 0.8819 - val_loss: 0.7623 - val_accuracy: 0.6944 - 289ms/epoch - 32ms/step
# Epoch 148/300
#
# Epoch 148: val_loss improved from 0.72786 to 0.71745, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4714 - accuracy: 0.9097 - val_loss: 0.7175 - val_accuracy: 0.7639 - 323ms/epoch - 36ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.71745
# 9/9 - 0s - loss: 0.5190 - accuracy: 0.8681 - val_loss: 0.7540 - val_accuracy: 0.7500 - 293ms/epoch - 33ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.71745
# 9/9 - 0s - loss: 0.5031 - accuracy: 0.9097 - val_loss: 0.7488 - val_accuracy: 0.7083 - 289ms/epoch - 32ms/step
# Epoch 151/300
#
# Epoch 151: val_loss improved from 0.71745 to 0.70404, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4958 - accuracy: 0.8819 - val_loss: 0.7040 - val_accuracy: 0.7361 - 366ms/epoch - 41ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.70404
# 9/9 - 0s - loss: 0.5107 - accuracy: 0.8403 - val_loss: 0.7725 - val_accuracy: 0.6667 - 334ms/epoch - 37ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.70404
# 9/9 - 0s - loss: 0.4814 - accuracy: 0.8819 - val_loss: 0.7131 - val_accuracy: 0.7361 - 291ms/epoch - 32ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.70404
# 9/9 - 0s - loss: 0.5006 - accuracy: 0.8611 - val_loss: 0.7182 - val_accuracy: 0.7778 - 295ms/epoch - 33ms/step
# Epoch 155/300
#
# Epoch 155: val_loss improved from 0.70404 to 0.70220, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4594 - accuracy: 0.8611 - val_loss: 0.7022 - val_accuracy: 0.7500 - 330ms/epoch - 37ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.70220
# 9/9 - 0s - loss: 0.4818 - accuracy: 0.8889 - val_loss: 0.7587 - val_accuracy: 0.7361 - 343ms/epoch - 38ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.70220
# 9/9 - 0s - loss: 0.5260 - accuracy: 0.8611 - val_loss: 0.7059 - val_accuracy: 0.7083 - 299ms/epoch - 33ms/step
# Epoch 158/300
#
# Epoch 158: val_loss improved from 0.70220 to 0.69156, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5062 - accuracy: 0.8750 - val_loss: 0.6916 - val_accuracy: 0.7778 - 322ms/epoch - 36ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.69156
# 9/9 - 0s - loss: 0.4814 - accuracy: 0.8750 - val_loss: 0.7140 - val_accuracy: 0.7222 - 344ms/epoch - 38ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.69156
# 9/9 - 0s - loss: 0.4811 - accuracy: 0.9028 - val_loss: 0.7182 - val_accuracy: 0.7222 - 286ms/epoch - 32ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.69156
# 9/9 - 0s - loss: 0.4486 - accuracy: 0.8889 - val_loss: 0.7416 - val_accuracy: 0.7500 - 298ms/epoch - 33ms/step
# Epoch 162/300
#
# Epoch 162: val_loss improved from 0.69156 to 0.66965, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4661 - accuracy: 0.9028 - val_loss: 0.6697 - val_accuracy: 0.7361 - 343ms/epoch - 38ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4660 - accuracy: 0.8958 - val_loss: 0.7014 - val_accuracy: 0.7222 - 387ms/epoch - 43ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4430 - accuracy: 0.9097 - val_loss: 0.6920 - val_accuracy: 0.7639 - 300ms/epoch - 33ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4702 - accuracy: 0.8958 - val_loss: 0.6974 - val_accuracy: 0.7778 - 302ms/epoch - 34ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4720 - accuracy: 0.8958 - val_loss: 0.6992 - val_accuracy: 0.7361 - 289ms/epoch - 32ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4721 - accuracy: 0.8889 - val_loss: 0.6986 - val_accuracy: 0.7500 - 291ms/epoch - 32ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4940 - accuracy: 0.8542 - val_loss: 0.7194 - val_accuracy: 0.7500 - 291ms/epoch - 32ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4770 - accuracy: 0.8681 - val_loss: 0.7167 - val_accuracy: 0.7500 - 290ms/epoch - 32ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4251 - accuracy: 0.9306 - val_loss: 0.6778 - val_accuracy: 0.7500 - 287ms/epoch - 32ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4383 - accuracy: 0.9167 - val_loss: 0.7525 - val_accuracy: 0.7500 - 287ms/epoch - 32ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4458 - accuracy: 0.9167 - val_loss: 0.7112 - val_accuracy: 0.6667 - 289ms/epoch - 32ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.66965
# 9/9 - 0s - loss: 0.4448 - accuracy: 0.9028 - val_loss: 0.7165 - val_accuracy: 0.7500 - 287ms/epoch - 32ms/step
# Epoch 174/300
#
# Epoch 174: val_loss improved from 0.66965 to 0.65975, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4505 - accuracy: 0.9028 - val_loss: 0.6597 - val_accuracy: 0.7778 - 325ms/epoch - 36ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.65975
# 9/9 - 0s - loss: 0.4133 - accuracy: 0.9583 - val_loss: 0.6831 - val_accuracy: 0.7361 - 346ms/epoch - 38ms/step
# Epoch 176/300
#
# Epoch 176: val_loss improved from 0.65975 to 0.65697, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4131 - accuracy: 0.9236 - val_loss: 0.6570 - val_accuracy: 0.7778 - 334ms/epoch - 37ms/step
# Epoch 177/300
#
# Epoch 177: val_loss improved from 0.65697 to 0.64592, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4633 - accuracy: 0.8889 - val_loss: 0.6459 - val_accuracy: 0.7917 - 331ms/epoch - 37ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4272 - accuracy: 0.9236 - val_loss: 0.6888 - val_accuracy: 0.7778 - 372ms/epoch - 41ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4410 - accuracy: 0.9306 - val_loss: 0.6637 - val_accuracy: 0.7639 - 291ms/epoch - 32ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4363 - accuracy: 0.9167 - val_loss: 0.6768 - val_accuracy: 0.7361 - 293ms/epoch - 33ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4245 - accuracy: 0.8889 - val_loss: 0.7010 - val_accuracy: 0.7222 - 304ms/epoch - 34ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4104 - accuracy: 0.9236 - val_loss: 0.6636 - val_accuracy: 0.7361 - 289ms/epoch - 32ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4786 - accuracy: 0.8750 - val_loss: 0.6790 - val_accuracy: 0.7917 - 282ms/epoch - 31ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4120 - accuracy: 0.8889 - val_loss: 0.7284 - val_accuracy: 0.7917 - 289ms/epoch - 32ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.3842 - accuracy: 0.9375 - val_loss: 0.6751 - val_accuracy: 0.7361 - 286ms/epoch - 32ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.3955 - accuracy: 0.9653 - val_loss: 0.6696 - val_accuracy: 0.7917 - 288ms/epoch - 32ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.3956 - accuracy: 0.9375 - val_loss: 0.6745 - val_accuracy: 0.7361 - 289ms/epoch - 32ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4102 - accuracy: 0.9028 - val_loss: 0.6480 - val_accuracy: 0.7500 - 315ms/epoch - 35ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4390 - accuracy: 0.8889 - val_loss: 0.6939 - val_accuracy: 0.7639 - 294ms/epoch - 33ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.4087 - accuracy: 0.9167 - val_loss: 0.6540 - val_accuracy: 0.7639 - 287ms/epoch - 32ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.64592
# 9/9 - 0s - loss: 0.3952 - accuracy: 0.9097 - val_loss: 0.6752 - val_accuracy: 0.7500 - 288ms/epoch - 32ms/step
# Epoch 192/300
#
# Epoch 192: val_loss improved from 0.64592 to 0.63889, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4153 - accuracy: 0.9028 - val_loss: 0.6389 - val_accuracy: 0.8056 - 330ms/epoch - 37ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.63889
# 9/9 - 0s - loss: 0.4440 - accuracy: 0.8750 - val_loss: 0.6406 - val_accuracy: 0.8056 - 391ms/epoch - 43ms/step
# Epoch 194/300
#
# Epoch 194: val_loss improved from 0.63889 to 0.62787, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4075 - accuracy: 0.8819 - val_loss: 0.6279 - val_accuracy: 0.8194 - 325ms/epoch - 36ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.62787
# 9/9 - 0s - loss: 0.3774 - accuracy: 0.9514 - val_loss: 0.6503 - val_accuracy: 0.7222 - 306ms/epoch - 34ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.62787
# 9/9 - 0s - loss: 0.4121 - accuracy: 0.9236 - val_loss: 0.6635 - val_accuracy: 0.7639 - 291ms/epoch - 32ms/step
# Epoch 197/300
#
# Epoch 197: val_loss improved from 0.62787 to 0.62574, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4143 - accuracy: 0.8681 - val_loss: 0.6257 - val_accuracy: 0.8333 - 325ms/epoch - 36ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.62574
# 9/9 - 0s - loss: 0.4184 - accuracy: 0.9167 - val_loss: 0.6486 - val_accuracy: 0.8056 - 343ms/epoch - 38ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.62574
# 9/9 - 0s - loss: 0.4152 - accuracy: 0.9236 - val_loss: 0.6796 - val_accuracy: 0.7917 - 294ms/epoch - 33ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.62574
# 9/9 - 0s - loss: 0.4010 - accuracy: 0.9028 - val_loss: 0.6672 - val_accuracy: 0.7500 - 285ms/epoch - 32ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.62574
# 9/9 - 0s - loss: 0.4329 - accuracy: 0.8819 - val_loss: 0.6832 - val_accuracy: 0.8056 - 291ms/epoch - 32ms/step
# Epoch 202/300
#
# Epoch 202: val_loss improved from 0.62574 to 0.61373, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3894 - accuracy: 0.9028 - val_loss: 0.6137 - val_accuracy: 0.8611 - 336ms/epoch - 37ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.61373
# 9/9 - 0s - loss: 0.4076 - accuracy: 0.8889 - val_loss: 0.6658 - val_accuracy: 0.7778 - 340ms/epoch - 38ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.61373
# 9/9 - 0s - loss: 0.3997 - accuracy: 0.9167 - val_loss: 0.6466 - val_accuracy: 0.8056 - 289ms/epoch - 32ms/step
# Epoch 205/300
#
# Epoch 205: val_loss improved from 0.61373 to 0.60724, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3787 - accuracy: 0.9097 - val_loss: 0.6072 - val_accuracy: 0.8056 - 333ms/epoch - 37ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3892 - accuracy: 0.9028 - val_loss: 0.6580 - val_accuracy: 0.7778 - 386ms/epoch - 43ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3907 - accuracy: 0.9097 - val_loss: 0.6844 - val_accuracy: 0.7917 - 303ms/epoch - 34ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3844 - accuracy: 0.9306 - val_loss: 0.6566 - val_accuracy: 0.7917 - 290ms/epoch - 32ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3777 - accuracy: 0.9097 - val_loss: 0.6362 - val_accuracy: 0.8056 - 290ms/epoch - 32ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3855 - accuracy: 0.9236 - val_loss: 0.6808 - val_accuracy: 0.7778 - 291ms/epoch - 32ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3476 - accuracy: 0.9444 - val_loss: 0.6438 - val_accuracy: 0.7778 - 308ms/epoch - 34ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3987 - accuracy: 0.9097 - val_loss: 0.6953 - val_accuracy: 0.7639 - 289ms/epoch - 32ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3988 - accuracy: 0.8958 - val_loss: 0.6165 - val_accuracy: 0.7917 - 293ms/epoch - 33ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3291 - accuracy: 0.9722 - val_loss: 0.6787 - val_accuracy: 0.8333 - 294ms/epoch - 33ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3882 - accuracy: 0.9236 - val_loss: 0.6571 - val_accuracy: 0.7639 - 283ms/epoch - 31ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3570 - accuracy: 0.9444 - val_loss: 0.6405 - val_accuracy: 0.8333 - 288ms/epoch - 32ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3422 - accuracy: 0.9306 - val_loss: 0.6252 - val_accuracy: 0.8056 - 282ms/epoch - 31ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3878 - accuracy: 0.9375 - val_loss: 0.6490 - val_accuracy: 0.8194 - 286ms/epoch - 32ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3290 - accuracy: 0.9514 - val_loss: 0.7151 - val_accuracy: 0.7361 - 292ms/epoch - 32ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.4066 - accuracy: 0.8750 - val_loss: 0.6403 - val_accuracy: 0.7917 - 295ms/epoch - 33ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.4134 - accuracy: 0.8889 - val_loss: 0.6422 - val_accuracy: 0.8056 - 293ms/epoch - 33ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3110 - accuracy: 0.9375 - val_loss: 0.6416 - val_accuracy: 0.7778 - 294ms/epoch - 33ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3649 - accuracy: 0.9375 - val_loss: 0.6184 - val_accuracy: 0.7778 - 296ms/epoch - 33ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.4031 - accuracy: 0.9028 - val_loss: 0.6457 - val_accuracy: 0.7500 - 289ms/epoch - 32ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3559 - accuracy: 0.9097 - val_loss: 0.6540 - val_accuracy: 0.8194 - 286ms/epoch - 32ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3358 - accuracy: 0.9306 - val_loss: 0.6223 - val_accuracy: 0.8194 - 290ms/epoch - 32ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.60724
# 9/9 - 0s - loss: 0.3870 - accuracy: 0.8958 - val_loss: 0.6476 - val_accuracy: 0.8056 - 294ms/epoch - 33ms/step
# Epoch 228/300
#
# Epoch 228: val_loss improved from 0.60724 to 0.60496, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3514 - accuracy: 0.9028 - val_loss: 0.6050 - val_accuracy: 0.8333 - 339ms/epoch - 38ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.60496
# 9/9 - 0s - loss: 0.4001 - accuracy: 0.8889 - val_loss: 0.6901 - val_accuracy: 0.8056 - 336ms/epoch - 37ms/step
# Epoch 230/300
#
# Epoch 230: val_loss improved from 0.60496 to 0.59827, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3277 - accuracy: 0.9306 - val_loss: 0.5983 - val_accuracy: 0.7917 - 335ms/epoch - 37ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.59827
# 9/9 - 0s - loss: 0.3505 - accuracy: 0.9097 - val_loss: 0.6945 - val_accuracy: 0.7917 - 286ms/epoch - 32ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.59827
# 9/9 - 0s - loss: 0.4401 - accuracy: 0.8403 - val_loss: 0.6304 - val_accuracy: 0.7917 - 292ms/epoch - 32ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.59827
# 9/9 - 0s - loss: 0.3834 - accuracy: 0.9236 - val_loss: 0.6369 - val_accuracy: 0.7917 - 293ms/epoch - 33ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.59827
# 9/9 - 0s - loss: 0.3365 - accuracy: 0.9583 - val_loss: 0.6472 - val_accuracy: 0.7917 - 295ms/epoch - 33ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.59827
# 9/9 - 0s - loss: 0.3417 - accuracy: 0.9444 - val_loss: 0.6865 - val_accuracy: 0.7778 - 309ms/epoch - 34ms/step
# Epoch 236/300
#
# Epoch 236: val_loss improved from 0.59827 to 0.59701, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3278 - accuracy: 0.9653 - val_loss: 0.5970 - val_accuracy: 0.8333 - 327ms/epoch - 36ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.59701
# 9/9 - 0s - loss: 0.3462 - accuracy: 0.8889 - val_loss: 0.6061 - val_accuracy: 0.8333 - 341ms/epoch - 38ms/step
# Epoch 238/300
#
# Epoch 238: val_loss improved from 0.59701 to 0.58807, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3392 - accuracy: 0.9583 - val_loss: 0.5881 - val_accuracy: 0.8194 - 332ms/epoch - 37ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3685 - accuracy: 0.9306 - val_loss: 0.6823 - val_accuracy: 0.7361 - 296ms/epoch - 33ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3247 - accuracy: 0.9514 - val_loss: 0.6366 - val_accuracy: 0.8056 - 300ms/epoch - 33ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.2892 - accuracy: 0.9583 - val_loss: 0.6028 - val_accuracy: 0.8194 - 292ms/epoch - 32ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3126 - accuracy: 0.9583 - val_loss: 0.6533 - val_accuracy: 0.8056 - 288ms/epoch - 32ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3492 - accuracy: 0.9236 - val_loss: 0.6671 - val_accuracy: 0.7778 - 288ms/epoch - 32ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.2822 - accuracy: 0.9722 - val_loss: 0.6216 - val_accuracy: 0.8333 - 287ms/epoch - 32ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3215 - accuracy: 0.9236 - val_loss: 0.5929 - val_accuracy: 0.8472 - 287ms/epoch - 32ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.58807
# 9/9 - 0s - loss: 0.3457 - accuracy: 0.9444 - val_loss: 0.6450 - val_accuracy: 0.7917 - 292ms/epoch - 32ms/step
# Epoch 247/300
#
# Epoch 247: val_loss improved from 0.58807 to 0.55952, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3969 - accuracy: 0.8958 - val_loss: 0.5595 - val_accuracy: 0.8333 - 342ms/epoch - 38ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.55952
# 9/9 - 0s - loss: 0.3222 - accuracy: 0.9306 - val_loss: 0.6244 - val_accuracy: 0.7500 - 311ms/epoch - 35ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.55952
# 9/9 - 0s - loss: 0.3546 - accuracy: 0.9028 - val_loss: 0.6456 - val_accuracy: 0.8056 - 284ms/epoch - 32ms/step
# Epoch 250/300
#
# Epoch 250: val_loss improved from 0.55952 to 0.55141, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3573 - accuracy: 0.9375 - val_loss: 0.5514 - val_accuracy: 0.8056 - 327ms/epoch - 36ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3352 - accuracy: 0.9097 - val_loss: 0.6402 - val_accuracy: 0.7778 - 357ms/epoch - 40ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3273 - accuracy: 0.9375 - val_loss: 0.5671 - val_accuracy: 0.8472 - 290ms/epoch - 32ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3076 - accuracy: 0.9306 - val_loss: 0.6027 - val_accuracy: 0.8056 - 293ms/epoch - 33ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3608 - accuracy: 0.9097 - val_loss: 0.5815 - val_accuracy: 0.8333 - 296ms/epoch - 33ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3031 - accuracy: 0.9583 - val_loss: 0.5932 - val_accuracy: 0.8333 - 292ms/epoch - 32ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3057 - accuracy: 0.9375 - val_loss: 0.6168 - val_accuracy: 0.8056 - 293ms/epoch - 33ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2938 - accuracy: 0.9583 - val_loss: 0.5950 - val_accuracy: 0.8056 - 290ms/epoch - 32ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2746 - accuracy: 0.9583 - val_loss: 0.6253 - val_accuracy: 0.7917 - 287ms/epoch - 32ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3144 - accuracy: 0.9306 - val_loss: 0.6035 - val_accuracy: 0.7917 - 295ms/epoch - 33ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3061 - accuracy: 0.9444 - val_loss: 0.6022 - val_accuracy: 0.8194 - 291ms/epoch - 32ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2921 - accuracy: 0.9375 - val_loss: 0.5603 - val_accuracy: 0.8333 - 290ms/epoch - 32ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3018 - accuracy: 0.9514 - val_loss: 0.5520 - val_accuracy: 0.8333 - 289ms/epoch - 32ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3009 - accuracy: 0.9444 - val_loss: 0.6195 - val_accuracy: 0.8472 - 290ms/epoch - 32ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3416 - accuracy: 0.9306 - val_loss: 0.5929 - val_accuracy: 0.7917 - 286ms/epoch - 32ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2918 - accuracy: 0.9792 - val_loss: 0.6429 - val_accuracy: 0.8333 - 285ms/epoch - 32ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3442 - accuracy: 0.9236 - val_loss: 0.5758 - val_accuracy: 0.8472 - 292ms/epoch - 32ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3257 - accuracy: 0.9306 - val_loss: 0.5744 - val_accuracy: 0.8333 - 290ms/epoch - 32ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2949 - accuracy: 0.9375 - val_loss: 0.6289 - val_accuracy: 0.7917 - 290ms/epoch - 32ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2896 - accuracy: 0.9653 - val_loss: 0.5704 - val_accuracy: 0.8333 - 298ms/epoch - 33ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3071 - accuracy: 0.9306 - val_loss: 0.6117 - val_accuracy: 0.8194 - 292ms/epoch - 32ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2989 - accuracy: 0.9444 - val_loss: 0.6159 - val_accuracy: 0.8056 - 292ms/epoch - 32ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3135 - accuracy: 0.9375 - val_loss: 0.6619 - val_accuracy: 0.8333 - 293ms/epoch - 33ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2867 - accuracy: 0.9583 - val_loss: 0.5837 - val_accuracy: 0.7917 - 297ms/epoch - 33ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2821 - accuracy: 0.9375 - val_loss: 0.5979 - val_accuracy: 0.8333 - 293ms/epoch - 33ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.3259 - accuracy: 0.9167 - val_loss: 0.6431 - val_accuracy: 0.8056 - 285ms/epoch - 32ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2732 - accuracy: 0.9583 - val_loss: 0.5891 - val_accuracy: 0.8194 - 290ms/epoch - 32ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2386 - accuracy: 0.9722 - val_loss: 0.6093 - val_accuracy: 0.7778 - 293ms/epoch - 33ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2708 - accuracy: 0.9653 - val_loss: 0.6146 - val_accuracy: 0.8333 - 291ms/epoch - 32ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2863 - accuracy: 0.9375 - val_loss: 0.6089 - val_accuracy: 0.8333 - 293ms/epoch - 33ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.55141
# 9/9 - 0s - loss: 0.2655 - accuracy: 0.9375 - val_loss: 0.6405 - val_accuracy: 0.7917 - 292ms/epoch - 32ms/step
# Epoch 281/300
#
# Epoch 281: val_loss improved from 0.55141 to 0.53287, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.2947 - accuracy: 0.9167 - val_loss: 0.5329 - val_accuracy: 0.7917 - 330ms/epoch - 37ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.53287
# 9/9 - 0s - loss: 0.3118 - accuracy: 0.9306 - val_loss: 0.6231 - val_accuracy: 0.7917 - 341ms/epoch - 38ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.53287
# 9/9 - 0s - loss: 0.2623 - accuracy: 0.9583 - val_loss: 0.5585 - val_accuracy: 0.8472 - 290ms/epoch - 32ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.53287
# 9/9 - 0s - loss: 0.2516 - accuracy: 0.9444 - val_loss: 0.5446 - val_accuracy: 0.8194 - 288ms/epoch - 32ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.53287
# 9/9 - 0s - loss: 0.3048 - accuracy: 0.9236 - val_loss: 0.6378 - val_accuracy: 0.7361 - 289ms/epoch - 32ms/step
# Epoch 286/300
#
# Epoch 286: val_loss improved from 0.53287 to 0.52656, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3269 - accuracy: 0.9097 - val_loss: 0.5266 - val_accuracy: 0.8472 - 345ms/epoch - 38ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2576 - accuracy: 0.9514 - val_loss: 0.5968 - val_accuracy: 0.8333 - 348ms/epoch - 39ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2715 - accuracy: 0.9444 - val_loss: 0.5479 - val_accuracy: 0.8750 - 294ms/epoch - 33ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2858 - accuracy: 0.9444 - val_loss: 0.5437 - val_accuracy: 0.8472 - 291ms/epoch - 32ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.3011 - accuracy: 0.9236 - val_loss: 0.5572 - val_accuracy: 0.8194 - 291ms/epoch - 32ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2592 - accuracy: 0.9444 - val_loss: 0.5873 - val_accuracy: 0.8333 - 288ms/epoch - 32ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2808 - accuracy: 0.9375 - val_loss: 0.5914 - val_accuracy: 0.8194 - 284ms/epoch - 32ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2840 - accuracy: 0.9444 - val_loss: 0.6016 - val_accuracy: 0.8056 - 290ms/epoch - 32ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2827 - accuracy: 0.9444 - val_loss: 0.5717 - val_accuracy: 0.8056 - 289ms/epoch - 32ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2712 - accuracy: 0.9306 - val_loss: 0.5702 - val_accuracy: 0.8333 - 288ms/epoch - 32ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2559 - accuracy: 0.9375 - val_loss: 0.5824 - val_accuracy: 0.8056 - 287ms/epoch - 32ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2711 - accuracy: 0.9444 - val_loss: 0.6027 - val_accuracy: 0.8333 - 289ms/epoch - 32ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2885 - accuracy: 0.9444 - val_loss: 0.6309 - val_accuracy: 0.8194 - 289ms/epoch - 32ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.3043 - accuracy: 0.9236 - val_loss: 0.6328 - val_accuracy: 0.7639 - 292ms/epoch - 32ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.52656
# 9/9 - 0s - loss: 0.2809 - accuracy: 0.9514 - val_loss: 0.6446 - val_accuracy: 0.7361 - 292ms/epoch - 32ms/step

# %%
X_test[0].shape
# Out:
# (60, 151, 1)

# %%
X_test.shape
# Out:
# (72, 60, 151, 1)

# %%
# load optimal weights
model.load_weights('checkpoint1.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 14ms/step
# Classification accuracy: 0.875000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score
from joblib import dump, load

# %%
temp = Y_test.argmax(axis=-1)
conf_matrix = confusion_matrix(temp, preds)
accuracy = accuracy_score(temp, preds)
precision = precision_score(temp, preds, average='weighted')
recall = recall_score(temp, preds, average='weighted')

print(f" Evaluation:")
dump(model, 'shallowConvNet.joblib')
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print("\n")

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title(f'Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
#  Evaluation:
# Accuracy: 0.88
# Precision: 0.88
# Recall: 0.88

# %%
# load optimal weights
model.load_weights('checkpoint1.h5')

# %%
model.predict(X_test).argmax(axis = -1)
# Out:
# 3/3 [==============================] - 0s 12ms/step
# array([3, 1, 2, 0, 3, 1, 2, 0, 1, 2, 0, 3, 1, 2, 3, 3, 1, 3, 0, 3, 0, 3,
#        0, 3, 1, 2, 3, 1, 2, 0, 3, 1, 2, 1, 3, 1, 2, 0, 3, 1, 2, 0, 1, 1,
#        2, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 0, 3, 1, 2, 1, 2, 1, 2, 0, 3, 0,
#        0, 3, 1, 2, 0, 3], dtype=int64)

# %%
##### class object oriented

import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk
import numpy as np
# import bluetooth
import csv
import pickle
import time
import matplotlib.pyplot as plt

class EEGPredictionGUI:
    def __init__(self, master):
        self.master = master
        master.title("EEG Prediction GUI")
        master.geometry("750x750")

        self.prediction_label = ttk.Label(master, text="")
        self.prediction_label.place(x=500, y=350)

        self.graphical_plot_label = ttk.Label(master)
        self.graphical_plot_label.place(x=200, y=20)

        self.eeg_plot_label = ttk.Label(master)
        self.eeg_plot_label.place(x=200, y=400)

        self.l = ttk.Label(master, text="EEG Prediction")
        self.l.config(font=("Courier", 14))
        self.l.place(x=10, y=45)

        self.predict_button = ttk.Button(master, text="Run Prediction", command=self.run_prediction_loop)
        self.predict_button.place(x=10, y=100)

        self.index = 0
        self.model = None
        self.X_test_loaded = None
        self.predicted_data = None
        self.sock = None

        self.load_model()
        self.load_eeg_data()
        # self.setup_bluetooth_connection()

    def load_model(self):
        try:
            # self.model = pickle.load(open('EEGNet.pkl', 'rb'))
            self.model = model
        except Exception as e:
            print(f"Error loading model: {e}")

    def load_eeg_data(self):
        try:
            with open('dataset/X.csv', 'r', newline='') as csvfile:
                reader = csv.reader(csvfile)
                data = []
                original_shape = None

                for row in reader:
                    if 'Original Shape:' in row:
                        original_shape = tuple(map(int, row[1].strip('()').split(',')))
                    else:
                        data.append([float(val) for val in row])

                if original_shape:
                    self.X_test_loaded = np.array(data).reshape(original_shape)
                    self.X_test_loaded = self.X_test_loaded[:4]
                    self.predicted_data = self.model.predict(self.X_test_loaded).argmax(axis=-1)
        except Exception as e:
            print(f"Error loading EEG data: {e}")

    # def setup_bluetooth_connection(self):
    #     try:
    #         esp32 = "ESP32test"
    #         address = "A0:A3:B3:AB:89:BA"
    #         devices = bluetooth.discover_devices()

    #         for addr in devices:
    #             if esp32 == bluetooth.lookup_name(addr):
    #                 address = addr
    #                 break

    #         port = 1
    #         self.sock = bluetooth.BluetoothSocket(bluetooth.RFCOMM)
    #         self.sock.connect((address, port))
    #     except Exception as e:
    #         print(f"Bluetooth Error: {e}")

    def run_prediction_loop(self):
        self.index = 0  # Reset index to 0
        self.run_prediction()

    def run_prediction(self):
        if self.index < len(self.predicted_data):
            pred = self.predicted_data[self.index]
            sample = self.X_test_loaded[self.index].squeeze()

            try:
                if pred == 0:
                    print("Forward")
                    self.prediction_label.config(text=f'Prediction: Forward')
                elif pred == 1:
                    print("Left")
                    self.prediction_label.config(text=f'Prediction: Left')
                elif pred == 2:
                    print("Right")
                    self.prediction_label.config(text=f'Prediction: Right')
                elif pred == 3:
                    print("Reverse")
                    self.prediction_label.config(text=f'Prediction: Reverse')
                self.sock.send(str(pred + 1))
            except Exception as e:
                print(f"Exception Occurred: {e}")

            time.sleep(3)

            # Plot EEG data
            plt.figure(figsize=(6, 4))
            plt.plot(sample)
            plt.xlabel('Time Step')
            plt.ylabel('EEG Value')
            plt.title(f'Sample {self.index} EEG Data')
            plt.savefig("temp_plot.png")
            plt.close()

            # Update graphical plot
            img = Image.open("temp_plot.png")
            img = img.resize((400, 300), Image.BILINEAR)
            img = ImageTk.PhotoImage(img)
            self.graphical_plot_label.config(image=img)
            self.graphical_plot_label.image = img

            # Plot EEG data with color bar
            plt.figure(figsize=(10, 6))
            plt.imshow(sample, aspect='auto', cmap='viridis')
            plt.colorbar(label='EEG Value')
            plt.xlabel('Time Step')
            plt.ylabel('Sample')
            plt.title(f'EEG Data - Prediction: {pred}')
            plt.savefig("temp_plot_eeg.png")
            plt.close()

            img_eeg = Image.open("temp_plot_eeg.png")
            img_eeg = img_eeg.resize((400, 300), Image.BILINEAR)
            img_eeg = ImageTk.PhotoImage(img_eeg)
            self.eeg_plot_label.config(image=img_eeg)
            self.eeg_plot_label.image = img_eeg

            # Update index for next prediction
            self.index += 1

            # Call run_prediction after a delay of 3 seconds
            self.master.after(300, self.run_prediction)

root = tk.Tk()
app = EEGPredictionGUI(root)
root.mainloop()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Forward
# Exception Occurred: 'NoneType' object has no attribute 'send'
# Left
# Exception Occurred: 'NoneType' object has no attribute 'send'
# Right
# Exception Occurred: 'NoneType' object has no attribute 'send'
# Reverse
# Exception Occurred: 'NoneType' object has no attribute 'send'
# Forward
# Exception Occurred: 'NoneType' object has no attribute 'send'
# Left
# Exception Occurred: 'NoneType' object has no attribute 'send'
